# %% [markdown]
# # **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - детально изучены многие тонкости данных
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - оценка выбросов
# - небольшое исправление графиков
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
# И вот доп ссылки на статьи по корреляции:
# - - [Величина и сила коэффициента корреляции](https://statpsy.ru/correlation/velicina/), тут есть табличка по тому, как интерпретировать корреляцию
# - [Линейный коэффициент корреляции Пирсона](https://statanaliz.info/statistica/korrelyaciya-i-regressiya/linejnyj-koefficient-korrelyacii-pirsona/)
# - [Корреляция и регрессия](https://stepik.org/lesson/8086/step/1?unit=1365), это небольшой курс на степике, в котором можно пройти только нужные тебе блоки
# - [Корреляция и каузальность](https://pikabu.ru/story/korrelyatsiya_i_kauzalnost_5956601)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - оценка выбросов
# - небольшое исправление графиков
# - пересмотр выводов
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении!
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# ---

# %% [markdown]
# # Введение

# %% [markdown]
# За основу исследования будет взята база объявлений о продаже квартир в Санкт-Петербурге и пригородах за несколько лет.
# Часть данных заполнена пользователями самостоятельно. Остальные данные получены автоматически на основе картографических данных.
# И те и другие могут содержать пропуски, ошибки и аномалии, которые будут обработаны в ходе исследования.

# %% [markdown]
# **Цель исследования:**
# 1. Изучить скорость продажи квартир и определить, сколько обычно дней на это требуется, а также определить, какие продажи можно считать быстрыми, а какие долгими.
# 2. Выявить факторы, оказывающие наибольшее влияние на общую стоимость объектов недвижимости.
# 3. Изучить различия в стоимости одного квадратного метра в зависимости от локации.
# 4. Определить, какое влияние на стоимость квартир оказывает удаленность от центра города.

# %% [markdown]
# Для достижения поставленных задач к изначальным данным будут добавлены дополнительные столбцы, содержащие следующую информацию:
# * цена одного квадратного метра
# * день, месяц и год публикации объявления
# * тип этажа квартиры (*первый, последний, другой*)
# * расстояние до цетра города в километрах

# %% [markdown]
# **Изучим имеющиеся данные:**
#
# ---
#
# |Столбец                  |Описание данных                                                 |
# |:------------------------|:---------------------------------------------------------------|
# |**airports_nearest**     |расстояние до ближайшего аэропорта в метрах (м)                 |
# |**balcony**              |число балконов                                                  |
# |**ceiling_height**       |высота потолков (м)                                             |
# |**cityCenters_nearest**  |расстояние до центра города (м)                                 |
# |**days_exposition**      |сколько дней было размещено объявление (от публикации до снятия)|
# |**first_day_exposition** |дата публикации                                                 |
# |**floor**                |этаж                                                            |
# |**floors_total**         |всего этажей в доме                                             |
# |**is_apartment**         |апартаменты (булев тип)                                         |
# |**kitchen_area**         |площадь кухни в квадратных метрах (м²)                          |
# |**last_price**           |цена на момент снятия с публикации                              |
# |**living_area**          |жилая площадь в квадратных метрах (м²)                          |
# |**locality_name**        |название населённого пункта                                     |
# |**open_plan**            |свободная планировка (булев тип)                                |
# |**parks_around3000**     |число парков в радиусе 3 км                                     |
# |**parks_nearest**        |расстояние до ближайшего парка (м)                              |
# |**ponds_around3000**     |число водоёмов в радиусе 3 км                                   |
# |**ponds_nearest**        |расстояние до ближайшего водоёма (м)                            |
# |**rooms**                |число комнат                                                    |
# |**studio**               |квартира-студия (булев тип)                                     |
# |**total_area**           |общая площадь квартиры в квадратных метрах (м²)                 |
# |**total_images**         |число фотографий квартиры в объявлении                          |
#
# ---

# %% [markdown]
# **Основные этапы исследования:**
# 1. Обзор данных с построением гистограмм
# 2. Предобработка данных
#     * поиск и обработка пропущенных значений
#     * оценка важности пропущенных значений и принятие решения об их удалении либо заполнении
#     * преобразование типов данных
#     * поиск и обработка явных и неявных дубликатов
# 3. Расчёт и добавление в таблцицу новых параметров
# 4. Исследовательский анализ данных
# 5. Оформление итогового вывода исследования
# ---

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - заголовок,
#
# - краткое описание проекта,
#
# - цель проекта,
#
# - описание данных,
#
# - план работы
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Спасибо опыту написания предыдущего проекта 😎
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
# импортируем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# загружаем данные из файла в датафрейм и сохраняем в переменную data
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Разделил ячейку с загрузкой библиотек и загрузкой данных из файла на две отдельные ячейки.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Молодец, что загружаешь все библиотеки в начале проекта. Так сложней случайно удалить ячейку с загрузкой нужной библиотеки и сделать код не работающим. А получатель отчета сразу поймет, какие библиотеки ты используешь и какие ему нужно установить для запуска проекта. 👍
#
# </div>

# %%
# выводим на экран 20 случайных строк data
pd.set_option('display.max_columns', 50) 
data.sample(20)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8066             20   4600000.0        36.5  2018-07-10T00:00:00      1
# 16010             7   4150000.0        43.0  2017-11-21T00:00:00      2
# 19109            19  17500000.0       144.2  2017-03-28T00:00:00      3
# 7745              0   3870000.0        32.0  2015-01-02T00:00:00      1
# 9303              8   1090000.0        31.0  2018-06-18T00:00:00      1
# 17303             5   7300000.0        52.1  2016-03-18T00:00:00      2
# 14537            17  14000000.0        95.0  2019-02-27T00:00:00      3
# 10957             8   3300000.0        60.0  2015-03-30T00:00:00      2
# 22395             6   3800000.0        47.0  2017-06-08T00:00:00      2
# 18329             7   3680000.0        44.1  2016-08-23T00:00:00      2
# 17505             9   4544000.0        32.7  2019-04-22T00:00:00      1
# 9889              1  12990000.0       191.0  2017-08-31T00:00:00      7
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Все хорошо, хочу дать рекомендацию. При выводе df.head() можно увидеть, что часть столбцов заменилась на «...»
#
# Чтобы это поправить можно поправить настройки pandas:
#
# ```python
# pd.set_option('display.max_columns', 50)
# ```
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Хоть комментарий выше и "зеленый", всё равно решил опробовать. Спасибо за совет!
#
# </div>

# %%
# выводим основную информацию о датафрейме с помощью метода info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# изучим статистическую своку столбцов data с помощью метода describe()
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %%
# выведем на экран гистограмму для всех числовых столбцов data
data.hist(figsize=(15, 20), ec='black', alpha=0.6, lw=1, color='b')       
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Отлично, построены гистограммы по всем столбцам!
#
# </div>

# %% [markdown]
# **Выводы по обзору данных:**
#
# **`total_images`** - встречаются объявления без фотографий. Маловероятно, что такие объявления будут интересны покупателям, но, тем не менее, они имеют право на существование.
# Исходя из данных на гистограмме, более половины объявлений имеют от 5 до 15 фото.
#
# **`last_price`** - подозрительные значения ***min*** *(12190)* и ***max*** *(763000000)*. Минимальное значение выглядит неправдоподобным. Максимальное - допустимо для элитного жилья. Медианного значение, на первый взгляд, реалистично.
#
# **`total_area`** - ***min*** равно ***12***. Речь, видимо идет о комнате, нежели о квартире.
# Исходя из данных на гистограмме, площадь подавляющего числа квартир менее 100 кв. м.
#
# **`rooms`** - ***min*** равно ***0***. Это возможно, если мы говорим о студии либо квартире со свободной планировкой. Проверим это. Максимальное значение равно ***19***. Такие квартиры могут встречаться, но, в таком случае, их должно быть крайне мало в сравнении с остальными.
# Исходя из данных на гистограмме, больше всего представлено двухкомнатных квартир.
#
# **`ceiling_height`** - медиана *(2.65)* правдоподобна. А вот значения ***min*** и ***max*** - явные аномалии.
#
# **`floors_total`** - ***max*** равно ***60***. Похоже на выброс. Жилые дома (в том числе с апартаментами) с такой этажностью в Санкт-Петербурге отсутствуют. К тому же, стандартное отклонение больше среднего значения в шесть раз, что также указывает на наличие выбросов.
# Исходя из данных на гистограмме, чаще встречаются квартиры, продаваемые в домах с количеством этажей до 10.
#
# **`living_area`** - ***min*** равно ***2***. Очевидная аномалия.
#
# **`floor`** - исходя из данных на гистограмме, около половины продаваемых квартир находятся на этаже не выше пятого.
#
# **`kitchen_area`** - медиана *(9.10)* более чем правдоподобна. Значение ***min*** *(1.3)* вызывает подозрения. Похоже на выброс. К тому же, стандартное отклонение больше среднего значения почти в шесть раз.
# Исходя из данных на гистограмме, чаще всего кухни имеют площадь до 12,5 кв. м.
#
# **`airports_nearest`** - ***min*** равно ***0***. Выброс.
#
# **`parks_nearest`** - минимальнео значение равно ***1 м***. Выглядит неправдоподобно.
#
# **`days_exposition`** - значения ***min*** *(1)* и ***max*** *(1580)* выглядят странно. В целом, такие значения возможны, но они могут внести нежелательные искажения в средние показатели.
# Исходя из данных на гистограмме, более половины квартир продаётся во временном диапозоне от ***1*** до ***165*** дней.
#
# Названия столбцов **`cityCenters_nearest`**, **`parks_around3000`**, **`ponds_around3000`** не соответствуют общему стилю. Исправим.
# В некоторых столбцах пропущен значительный объём данных.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хороший, красиво оформленный, промежуточный вывод, сразу понятно, что будет далее в предобработке.
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Переименование столбцов

# %%
# меняем названия отдельных столбцов с помощью метода rename()
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest',
                           'parks_around3000': 'parks_around_3000',
                           'ponds_around3000': 'ponds_around_3000'})
# названия столбцов приведены к общему стилю, то есть к "змеиному" регистру
# проверим
pd.set_option('display.max_columns', 50) 
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# ***Вывод по переименованию столбцов:***
#
# ***Названия столбцов `cityCenters_nearest`, `parks_around3000` и `ponds_around3000` приведены к единому стилю с остальными столбцами датасета.***
#
# ---

# %% [markdown]
# #### Поиск и обработка пропущенных значений

# %%
# выведем на экран количество пропущенных значений для каждого столбца
print(data.isna().sum())
print()

# посчитаем общее количетво пропусков в датафрейме по всем столбцам
print('Всего пропусков:', data.isna().sum().sum())

# построим круговую диаграмму распределения пропусков по столбцам
data.isna().sum().plot(kind='pie', figsize=(10, 10), legend=False)
plt.ylabel(None);
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#
# Всего пропусков: 101441

# %%
# выведем на экран количество пропусков в процентах
# отсортируем столбцы по убыванию пропущенных значений
print((data.isna().sum() / data.shape[0] * 100).round(2).sort_values(ascending=False))

# построим столбчатую диаграмму, отражающую количество пропущенных значений в каждом столбце 
# в процентах от общего количество строк
((data.isna().sum() / data.shape[0] * 100).round(2).sort_values()
    .plot(
    kind='barh', 
    figsize=(10,6), 
    color='green', 
    grid=True))
plt.show()
# Out:
# is_apartment            88.29
# parks_nearest           65.91
# ponds_nearest           61.56
# balcony                 48.61
# ceiling_height          38.80
# airports_nearest        23.38
# city_centers_nearest    23.29
# ponds_around_3000       23.28
# parks_around_3000       23.28
# days_exposition         13.42
# kitchen_area             9.61
# living_area              8.03
# floors_total             0.36
# locality_name            0.21
# total_images             0.00
# last_price               0.00
# studio                   0.00
# floor                    0.00
# rooms                    0.00
# first_day_exposition     0.00
# total_area               0.00
# open_plan                0.00
# dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что изучено соотношение пропущенных данных, это отличная практика.
#
# </div>

# %%
# с помощью цикла создадим переменную с названиями столбцов, в которых есть пропуски
data_col_with_missing_values = []
for col in data:
    if (data[col].isna().sum()) > 0 in data[col]:
        data_col_with_missing_values.append(col)
# проверяем работу цикла
data_col_with_missing_values
# Out:
# ['ceiling_height',
#  'floors_total',
#  'living_area',
#  'is_apartment',
#  'kitchen_area',
#  'balcony',
#  'locality_name',
#  'airports_nearest',
#  'city_centers_nearest',
#  'parks_around_3000',
#  'parks_nearest',
#  'ponds_around_3000',
#  'ponds_nearest',
#  'days_exposition']

# %%
# с помощью цикла выведем на экран информацию об уникальных и пропущенных значениях датафрейма
print(f'Общее количество строк в data: {len(data)} \n')
for col in data[data_col_with_missing_values]:
    print(f'Количество уникальных значений столбца {col}: {len(data[data_col_with_missing_values][col].unique())}')
    print(f'Количество пропущенных значений столбца {col}: {data[data_col_with_missing_values][col].isna().sum()} \n')
# Out:
# Общее количество строк в data: 23699
#
# Количество уникальных значений столбца ceiling_height: 184
# Количество пропущенных значений столбца ceiling_height: 9195
#
# Количество уникальных значений столбца floors_total: 37
# Количество пропущенных значений столбца floors_total: 86
#
# Количество уникальных значений столбца living_area: 1783
# Количество пропущенных значений столбца living_area: 1903
#
# Количество уникальных значений столбца is_apartment: 3
# Количество пропущенных значений столбца is_apartment: 20924
#
# Количество уникальных значений столбца kitchen_area: 972
# Количество пропущенных значений столбца kitchen_area: 2278
#
# Количество уникальных значений столбца balcony: 7
# Количество пропущенных значений столбца balcony: 11519
#
# Количество уникальных значений столбца locality_name: 365
# Количество пропущенных значений столбца locality_name: 49
#
# Количество уникальных значений столбца airports_nearest: 8276
# ...

# %%
# из полученных данных создадим отдельный датафрейм для более удобного восприятия
lines = [
    ['ceiling_height', 184, 9195],
    ['floors_total', 37, 86],
    ['living_area',1783, 1903],
    ['is_apartment', 3, 20924],
    ['kitchen_area', 972, 2278],
    ['balcony', 7, 11519],
    ['locality_name', 365, 49],
    ['airports_nearest', 8276,5542],
    ['city_centers_nearest', 7643, 5519],
    ['parks_around_3000', 5, 5518],
    ['parks_nearest', 996, 15620],
    ['ponds_around_3000', 5, 5518],
    ['ponds_nearest', 1097, 14589],
    ['days_exposition', 1142, 3181]
]
columns = ['Столбец','УникЗнач', 'ПропЗнач']

table_of_missing_values = pd.DataFrame(data=lines, columns=columns)

# добавляем столбец с количестовм пропусков в процентах от общего количества строк
table_of_missing_values['ПропЗнач, %'] = (table_of_missing_values['ПропЗнач'] / data.shape[0]*100).round(2)

print('Описание к таблице:\n',
      'УникЗнач - количество уникальных значений \n', 
      'ПропЗнач - количество пропущенных значений \n',
      'ПропЗнач, % - процент пропущенных значений от общего количества строк \n')

print('Общее количество строк:', data.shape[0])

# выводим получившийся датафрейм на экран, отсортировав по убыванию процента пропусков
table_of_missing_values.sort_values(by='ПропЗнач, %', ascending=False).reset_index(drop=True)
# Out:
# Описание к таблице:
#  УникЗнач - количество уникальных значений
#  ПропЗнач - количество пропущенных значений
#  ПропЗнач, % - процент пропущенных значений от общего количества строк
#
# Общее количество строк: 23699
#                  Столбец  УникЗнач  ПропЗнач  ПропЗнач, %
# 0           is_apartment         3     20924        88.29
# 1          parks_nearest       996     15620        65.91
# 2          ponds_nearest      1097     14589        61.56
# 3                balcony         7     11519        48.61
# 4         ceiling_height       184      9195        38.80
# 5       airports_nearest      8276      5542        23.38
# 6   city_centers_nearest      7643      5519        23.29
# 7      parks_around_3000         5      5518        23.28
# 8      ponds_around_3000         5      5518        23.28
# 9        days_exposition      1142      3181        13.42
# 10          kitchen_area       972      2278         9.61
# 11           living_area      1783      1903         8.03
# ...

# %%
# посчитаем общее количество столбцов и количество столбцов, содержащих пропуски
print('Количество столбцов всего:', data.shape[1])
print('Количество столбцов с пропусками:', ((data.isna().sum() > 0) == True).sum())
# Out:
# Количество столбцов всего: 22
# Количество столбцов с пропусками: 14

# %% [markdown]
# **Выводы по пропущенным значениям:**
#
# **`is_apartment`** *(является ли помещение апартаменатми)* - Пропуски: **20924 (88.29%)**. В данном столбце наблюдаем больше всего пропущенных значений. Логично предположить, что если автор объявления не указал, что продаваемый объект - это апартаменты (***True***), то, вероятнее всего, речь в таком объявлении идет не об апартаментах, а об обычной квартире. Скорее всего, продавцы просто не сочли нужным указывать этот параметр. Поэтому **правильнее будет заменить пропуски** на ***False***, так как превалирование количества обычных квартир над апартаметами - нормальное явление для рынка недвижимости.
#
# **`parks_nearest`** *(расстояние до ближайшего парка (м))* - Пропуски: **15620 (65.91%)**. Возможная причина возникновения пропусков - ошибка при загрузке картографических данных. Либо на момент публикации части объявлений отображение подобной информации не подразумевалось в принципе, а появилось позже. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`ponds_nearest`** *(расстояние до ближайшего водоёма (м))*- Пропуски: **14589 (61.56%)**. Возможная причина возникновения пропусков - ошибка при загрузке картографических данных. Либо на момент публикации части объявлений отображение подобной информации не подразумевалось в принципе, а появилось позже. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`balcony`** *(число балконов)* - Пропуски: **11519 (48.61%)**. В столбце `balcony` не заполнено **11519** строк, что составляет **48.61%** от их общего количества. Вероятнее всего, если продавец не указал в объявлении количество балконов, то в квартире их нет. Поэтому **целессобразно будет заменить все пропущенные значения** данного столбца на **0**.
#
# **`ceiling_height`** *(высота потолков (м))* - Пропуски: **9195 (38.80%)**. В столбце `ceiling_height` не заполнено **9195** строк, что составляет **38.80%** от их общего количества. Считаю оптимальным вариантом **заменить пропущенные значения на медиану**.
#
# **`airports_nearest`** *(расстояние до ближайшего аэропорта в метрах (м))* - Пропуски: **5542 (23.38%)**. Возможная причина возникновения пропусков - ошибка при загрузке картографических данных. Либо на момент публикации части объявлений отображение подобной информации не подразумевалось в принципе, а появилось позже. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`city_centers_nearest`** *(расстояние до центра города (м))* - Пропуски: **5519 (23.29%)**. Возможная причина возникновения пропусков - ошибка при загрузке картографических данных. Либо на момент публикации части объявлений отображение подобной информации не подразумевалось в принципе, а появилось позже. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`parks_around_3000`** *(число парков в радиусе 3 км)* - Пропуски: **5518 (23.28%)**. Возможная причина возникновения пропусков - ошибка при загрузке картографических данных. Либо на момент публикации части объявлений отображение подобной информации не подразумевалось в принципе, а появилось позже. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`ponds_around_3000`** *(число водоёмов в радиусе 3 км)* - Пропуски: **5518 (23.28%)**. Возможная причина возникновения пропусков - ошибка при загрузке картографических данных. Либо на момент публикации части объявлений отображение подобной информации не подразумевалось в принципе, а появилось позже. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`days_exposition`** *(сколько дней было размещено объявление (от публикации до снятия))* - Пропуски: **3181 (13.42%)**. Их появление, вероятнее всего, является следствием технического сбоя при записи данных. Либо по неизвестным нам причинам авторы этих объявлений удалили их сразу же после публикации. Заполнение пропусков в данном столбце логичными значениями не представляется возможным, поэтому **оставим их без изменений**.
#
# **`kitchen_area`** *(площадь кухни в квадратных метрах (м²))* - Пропуски: **2278 (9.61%)**. Такие значения могли появится, если автор объявления о продаже намеренно не стал заполнять соответствующее поле. Также данное поле могли не заполнять для студий или квартир со свободной планировкой. Если пропуски содержатся в таких квартирах, то их **можно заменить** на **0**. Пропусков менее **10%**. Они не должны оказать значительного влияния на исследование. Но, тем не менее, остальные пропуски **можно заменить, зная среднюю долю** площади кухни в общей площади квартиры.
#
# **`living_area`** *(жилая площадь в квадратных метрах (м²))* - Пропуски: **1903 (8.03%)**. Такие значения также могли появится, если автор объявления о продаже намеренно не стал заполнять соответствующее поле. К примеру, потому, что продавец на момент публикации объявления не помнил этого параметра, а замем забыл его внести. Пропусков **8%**. Они не должны оказать значительного влияния на исследование. Но, тем не менее, остальные пропуски **можно заменить, зная среднюю долю** жилой площади в общей площади квартиры.
#
# **`floors_total`** *(всего этажей в доме)* - Пропуски: **86 (0.36%)**. Пропусков в данном столбце очень мало. Они не окажут влияния на исследование. Но, тем не менее, мы можем заполнить эти пропуски медианными значениями. Но важно учитывать, что значение этажа, указанное в объялении, не может быть больше общего количества этажей в доме. Дабы избежать подобной ошибки, **заполним пропуски в столбце `floors_total` медианными значениями** для сгруппированных по каждому этажу значений `floor`.
#
# **`locality_name`** *(название населённого пункта)* - Пропуски: **49 (0.21%)**. Пропусков очень мало, и на исследование они не окажут влияния, но, тем не менее, **часть их них можно попробовать заменить** на `Санкт-Петербург`, если по параметру расстояния до цента города они входят в городскую черту. Тем более, продавцы квартир, находящихся непосредственно в Санкт-Петербурге, могли счесть необязательным дополнительно прописывать этот параметр или, возможно, указали эту информацию не в специально отведённом поле, а в описании к объявлению.
# Появление пропусков в данном столбце также возможно из-за технического сбоя при записи данных либо из-за человеческого фактора (неверный ввод данных либо продавец и вовсе забыл заполнить это поле).
#
# Обратим внимание на группы столбцов `parks_nearest`, `ponds_nearest` и `airports_nearest`, `city_centers_nearest`, `ponds_around_3000`, `parks_around_3000`. Они имеют похожее количество пропусков: **15620**, **14589** и **5542**, **5519**, **5518**, **5518**. Дополнительный аргумент в пользу того, что пропуски возникли из-за того, что на момент публикации этих объявлений подобная информация не собиралась по тем или иным причинам. Позже попробуем это проверить и отыскать взаимосвязи после добавления столбца с годом публикации.

# %%
# Проверим, какие уникальные значения содержит столбец 'is_apartment'
print('Количество уникальных значений', len(data['is_apartment'].unique()))
print('Уникальные значения столбца is_apartment:', data['is_apartment'].unique())

# изучим соотношение аппартаментов и не аппартаментов среди заполненных строк
print('Общее количество строк:', len(data['is_apartment']))
data.groupby('is_apartment', as_index=False).agg({'floor':'count'}).rename(columns={'floor': 'count'})
# Out:
# Количество уникальных значений 3
# Уникальные значения столбца is_apartment: [nan False True]
# Общее количество строк: 23699
#    is_apartment  count
# 0         False   2725
# 1          True     50

# %% [markdown]
# Действительно, апартаментов гораздо меньше, чем обычных квартир.

# %%
# заменим все пропущенные значения в столбце 'is_apartment' на False (не апартаменты)
data['is_apartment'] = data['is_apartment'].fillna(value=False)

# %%
# снова проверим наличие пропусков
data['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# ***Столбец `is_apartment` заполняется одним из двух значений:***
#
# ***True - объект является апартаментами***
# ***False - объект не является апартаментами, то есть это обычная квартира***
#
# ***Все пропущенные значения в столбце `is_apartment` заполнили значением "False" (не апартаменты), так как, скорее всего, пропуски в данном столбце связаны с тем, что объект недвижимости является обычной квартирой, а не апартаментами.***
#
# ---

# %%
# заменим все пропуски в столбце 'balcony' на 0 
data['balcony'] = data['balcony'].fillna(0)

# %%
# снова проверим наличие пропусков
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# ***Столбец `balcony` отображает количество балконов в квартире***
#
# ***Если продавец не заполнил данное поле в объявлении, то, скорее всего, балконов в квартире нет.***
#
# ***Поэтому все пропущенные значения в столбце `balcony` заполнили значением "0" (балконы в квартире отсутствуют).***
#
# ---

# %%
# пропуски в столбце 'ceiling_height' заполним медианным значением высоты потолков
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %%
# снова проверим наличие пропусков
data['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# ***Все пропуски в столбце `ceiling_height` заполнили медианным значением, так как медиана наиболее устойчива к выбросам. Медиана для `ceiling_height` равна 2.65, что выглядит весьма правдоподобно.***
#
# ---

# %%
# рассчитаем среднюю долю площади кухни от общей площади c округлением до трёх знаков после запятой 
kitchen_area_ratio = (data['kitchen_area'] / data['total_area']).mean()
kitchen_area_ratio.round(3)
# Out:
# 0.187

# %%
# посчитаем коэффициент корреляции между площадью кухни и общей площадью
print(data['kitchen_area'].corr(data['total_area']).round(2))

# построим диаграмму рассеяния
data.plot(x='kitchen_area', y='total_area', kind='scatter', figsize=(10, 10), alpha=0.3)
plt.show()
# Out:
# 0.61

# %% [markdown]
# Наблюдаем, в целом, положительную зависимость площади кухни от общей площади объекта

# %%
# посчитаем количество студий
data[data['studio']==True]['rooms'].count()
# Out:
# 149

# %%
# посчитаем количество студий, в которых есть пропуски в столбце 'kitchen_area'
data[(data['studio']==True) & (data['kitchen_area'].isna())]['rooms'].count()
# Out:
# 149

# %%
# посчитаем количество квартир со свободной планировкой
data[data['open_plan']==True]['rooms'].count()
# Out:
# 67

# %%
# посчитаем количество квартир со свободной планировкой, в которых есть пропуски в столбце 'kitchen_area'
data[(data['open_plan']==True) & (data['kitchen_area'].isna())]['rooms'].count()
# Out:
# 67

# %% [markdown]
# Во всех объявлениях со студиями и квартирами со свободной планировкой не указана палощадь кухни. Её в них и не должно быть.
# Поэтому заполним пропуски в `kitchen_area` во всех студиях и квартирах со свободной планировкой значением **0**.

# %%
# заполняем пропуски для студий
data.loc[data['studio'] == True, 'kitchen_area'] = 0

# заполняем пропуски для квартир со свободной планировкой
data.loc[data['open_plan'] == True, 'kitchen_area'] = 0

# %%
# зная среднюю долю площади кухни в общей площади заменим оставшиеся пропуски в столбце 'kitchen_area'
data['kitchen_area'].fillna(kitchen_area_ratio * data['total_area'], inplace=True)

# %%
# снова проверим наличие пропусков
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# ***В столбце `kitchen_area` содержатся данные о площади кухонь в продаваемых объектах.***
#
# ***Столбец `total_area` (общая площадь) не содержит пропусков.***
#
# ***Благодаря этому, определив, что площадь кухни имеет положительную зависимость от общей площади квартиры (коэффициент корреляции равен 0.61) и рассчитав среднюю долю площади кухни в общей площади (0.187), заполнили пропущенные значения в столбце `kitchen_area`.***
#
# ---

# %%
# посчитаем коэффициент корреляции между жилой площадью и общей
print(data['living_area'].corr(data['total_area']).round(2))

# построим диаграмму рассеяния
data.plot(x='living_area', y='total_area', kind='scatter', figsize=(10, 10), alpha=0.3, ylim=(0, 600), xlim=(0, 400))
plt.show()
# Out:
# 0.94

# %% [markdown]
# Между значениями в данных столбцах наблюдаем прямую положительную зависимость.
# Чем больше жилая площадь, тем больше общая, и наоборот.

# %%
# рассчитаем среднюю долю жилой площади от общей c округлением до трёх знаков после запятой 
living_area_ratio = (data['living_area'] / data['total_area']).mean()
living_area_ratio.round(3)
# Out:
# 0.565

# %%
# зная среднюю долю жилой площади в общей площади заменим все пропуски в столбце 'living_area'
data['living_area'].fillna(living_area_ratio * data['total_area'], inplace=True)

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Важно понимать, что при данном заполнении пропусков может получиться, что `living_area` + `kitchen_area` больше `total_area`. Но в нашем случае, это не критично.
#
# </div>

# %%
# проверим гипотезу ревьюера
# узнаем, есть ли строки в data, где 'living_area' + 'kitchen_area' больше 'total_area'
len(data.query('living_area + kitchen_area > total_area'))
# Out:
# 103

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Да, действительно. После заполнения пропусков по средней доле в **103** строках общая площадь оказалась меньше суммы жилой площади и площади кухни. Об этом я не подумал. Спасибо за ценное замечание! Буду учитывать это в будущем! 👌
#
# Но, как ты отметил, это не критично.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Супер, верная обработка 👍
#
# </div>

# %%
# снова проверим наличие пропусков
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# ***В столбце `living_area` содержатся данные о жилой площади в продаваемых объектах.***
#
# ***Столбец `total_area` (общая площадь) не содержит пропусков.***
#
# ***Благодаря этому, определив, что жилая площадь имеет положительную зависимость от общей площади квартиры (коэффициент корреляции равен 0.94) и рассчитав среднюю долю жилой площади в общей площади (0.565), заполнили пропущенные значения в столбце `living_area`.***
#
# ---

# %%
# выведем на экран первые 10 строк столбцов 'floors_total' и 'floor', где в 'floors_total' есть пропуски
data[data['floors_total'].isna() == True][['floors_total', 'floor']].head(10)
# Out:
#       floors_total  floor
# 186            NaN      4
# 237            NaN      1
# 457            NaN     12
# 671            NaN      8
# 1757           NaN      9
# 1930           NaN      4
# 2392           NaN     22
# 2846           NaN     15
# 2952           NaN      6
# 3031           NaN     12

# %%
# сохраним в отдельную переменную индексы строк data, в которых в столбце 'floors_total' имеются пропуски
floors_total_check = data.index [data['floors_total'].isna() == True]
# и выведем результат на экран
floors_total_check
# Out:
# Int64Index([  186,   237,   457,   671,  1757,  1930,  2392,  2846,  2952,
#              3031,  3438,  3817,  3831,  4140,  4617,  4848,  4901,  5146,
#              5187,  5784,  5958,  6030,  6136,  6288,  7508,  7662,  7922,
#              8478,  8986,  9023,  9415,  9979, 10004, 10013, 10027, 10058,
#             10259, 10319, 10351, 10486, 10531, 10568, 10662, 10880, 10983,
#             11129, 11292, 11328, 11389, 11425, 12104, 12352, 12399, 12739,
#             13438, 13622, 13955, 14094, 14153, 14264, 14526, 14717, 15989,
#             16496, 16549, 16591, 16668, 16850, 17498, 17721, 17925, 18832,
#             19133, 19350, 19452, 20146, 20250, 20738, 21273, 21651, 21753,
#             22542, 22656, 22808, 23590, 23658],
#            dtype='int64')

# %%
# проверим, переменная floors_total_check должна содержать 86 индексов
len(floors_total_check)
# Out:
# 86

# %%
# создадим цикл для заполенния пропусков в 'floors_total' медианными значениями в зависимости эатажа квартиры
for i in data['floor'].unique():
    data.loc[(data['floor'] == i) & (data['floors_total'].isna()), 'floors_total'] = \
    data.loc[(data['floor'] == i), 'floors_total'].median()

# %%
# снова проверим наличие пропусков
print(data['floors_total'].describe())
data['floors_total'].isna().sum()
# Out:
# count    23699.000000
# mean        10.681759
# std          6.599383
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
# 0

# %%
# проверим результат заполнения пропусков, 
# помня, что в каждой отдельной строке значение 'floor' не должно быть больше значения 'floors_total'
a = data['floors_total'][floors_total_check]
b = data['floor'][floors_total_check]

ab = pd.concat([a, b], axis= 1)
ab.head(10)
# Out:
#       floors_total  floor
# 186            5.0      4
# 237            5.0      1
# 457           16.0     12
# 671           10.0      8
# 1757          10.0      9
# 1930           5.0      4
# 2392          25.0     22
# 2846          17.0     15
# 2952           9.0      6
# 3031          16.0     12

# %% [markdown]
# Замена пропусков прошла корректно.
# Все пропущенные значения в столбце `floors_total` заполнены.

# %% [markdown]
# ***Столбец `floors_total` содержит данные об общем количестве этажей в доме.***
#
# ***Используя цикл, заполнили пропуски в данном столбце медианными значениями общего количества этажей среди квартир, находящихся на тех же этажах, что и квартиры с пропусками в столбце `floors_total`.***
#
# ---

# %%
# рассчитаем медианное расстояние до центра города среди объявлений,
# где в столбце 'locality_name' указано 'Санкт-Петербург' и выведем его на экран
spb_to_center_median = data[data['locality_name'] == 'Санкт-Петербург']['city_centers_nearest'].median()
spb_to_center_median
# Out:
# 12244.5

# %% [markdown]
# Данные правдоподобны. Будем считать, что квартиры с пропуском в столбце `locality_name` находятся в черте Санкт-Петербурга, если у них в столбце `city_centers_nearest` указано значение **12244.5** или меньше.
#
# Теперь заполним пропуски `locality_name`, где значение `city_centers_nearest` меньше или равно **12244.5**, значением `Санкт-Петербург`.

# %%
# для этого создаим цикл
for i in data['city_centers_nearest'].unique():
    data.loc[(data['city_centers_nearest'] <= spb_to_center_median) & (data['locality_name'].isna()), 'locality_name'] = \
    data['locality_name'].fillna('Санкт-Петербург')

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Хорошо, что пропуски заполнены сгруппированными данными, тут можно было применить метод [transform](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transform.html)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Не буду утверждать на 100%, но мне кажется, что на одной из встреч наш наставник рассказывал про метод **transrom**, но также отметил, что некоторые ревьюеры могут не поддерживать его применение студентами. Возможно, поэтому я и не стал его применять. И, к тому же, в учебной программе мы этот метод пока не изучали.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# Странно, классный метод, пользуюсь им и советую)
#
# </div>

# %%
# снова проверим наличие пропусков
data['locality_name'].isna().sum()
# Out:
# 23

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Пропуски заполнены корректно 😃
#
# </div>

# %% [markdown]
# Удалось сократить количество пропусков в столбце `locality_name` более чем на половину.
#
# Остальные объекты могут оказаться уже за границами Санкт-Петербурга, и выбрать название населенного пункта для них не представляется возможным ввиду недостаточности данных. Поэтому их оставим без изменений.

# %% [markdown]
# ***Столбец `locality_name` содержит информацию о названии населённого пункта, в котором располагается продавамый объект недвижимости.***
#
# ***Рассчитав медианное расстояние до центра города среди объявлений, где в столбце `locality_name` указано "Санкт-Петербург" (12244.5 м), и исходя из того, что объекты с неуказанной локацией, находящиеся в пределах данного радиуса, также должны находится в границах Санкт-Петербурга, с помощью цикла заполнили пропуски в данном столбце значением "Санкт-Петербург".***
#
# ---

# %% [markdown]
# ***Общий вывод по обработке пропусков:***
#
# ***Пропущенные значения в столбцах датасета были изучены и, там гед это возможно, заполнены логичными обоснованными значениями.***
#
# ---

# %% [markdown]
# #### Преобразование типов данных

# %%
# еще раз просмотрим основную информацию о датафрейме
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23676 non-null  object
# ...

# %% [markdown]
# `first_day_exposition` - тип данных должен быть ***datetime***, то есть формат даты и времени.
#
# `floors_total` - тип данных должен быть ***int***, так как количество этажей в доме - это целое число.
#
# `is_apartment` - ранее тип данных был ***object***, но в результате заполнения всех пропусков тип изменился на ***bool***. Так и должно быть.
#
# `balcony` - тип данных должен быть ***int***, так как количество балконов в квартире - это целое число.
#
# `airports_nearest` - тип данных должен быть ***int***, так как расстояние указано в целых метрах.
#
# `city_centers_nearest` - тип данных должен быть ***int***, так как расстояние указано в целых метрах.
#
# `parks_around_3000` - тип данных должен быть ***int***, так как количество ближайших парков - это целое число.
#
# `parks_nearest` - тип данных должен быть ***int***, так как расстояние указано в целых метрах.
#
# `ponds_around_3000` - тип данных должен быть ***int***, так как количество ближайших водоёмов - это целое число.
#
# `ponds_nearest` - тип данных должен быть ***int***, так как расстояние указано в целых метрах.
#
# `days_exposition` - тип данных должен быть ***int***, так как количество дней - это целое число.

# %%
# меняем тип данных в столбце 'first_day_exposition' на datetime
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])

# меняем тип данных в столбце 'floors_total' на целочисленные
data['floors_total'] = data['floors_total'].astype(int)

# меняем тип данных в столбце 'balcony' на целочисленные
data['balcony'] = data['balcony'].astype(int)

# меняем тип данных в столбце 'last_price' на целочисленные для удобства просмотра, то есть исключаем копейки
data['last_price'] = data['last_price'].astype('int')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что преобразования типов все в одном месте.
#
# </div>

# %% [markdown]
# Ввиду того, что мы не стали заполнять пропущенные значения в столбцах:
# - `airports_nearest`,
# - `city_centers_nearest`,
# - `parks_nearest`,
# - `ponds_nearest`,
# - `days_exposition`,
# - `ponds_around3000`,
# - `parks_around3000`,
#
# данные в них не могут быть изменены на ***int*** из-за наличия значений ***NaN***.

# %%
# проверим результат изменения типов данных
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23676 non-null  object
# ...

# %% [markdown]
# Типы данных там, где это возможно, приведены в порядок.

# %% [markdown]
# ***Вывод по преобразованию типов данных:***
#
# ***Изучив типы данных во всех столбцах датасета, пришли к выводу, что некоторые из них некорректны и могут оказать негативное влияние на ход исследования. В связи с этим, для достижения поставленных целей проекта, было принято решение изменить типы данных там, где это возможно, на соответствующие действительности.***
#
# ---

# %% [markdown]
# #### Поиск и обработка явных и неявных дубликатов

# %%
# проверим данные на наличие явных дубликатов
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты отсутствуют.

# %%
# изучим уникальные значения столбцов на предмет наличия аномалий и неявных дубликатов
for col in data:
    print(f'Уникальные значения столбца {col}: {data[col].unique()}')
    print(f'Количество уникальных значений столбца {col}: {len(data[col].unique())} \n')
# Out:
# Уникальные значения столбца total_images: [20  7 10  0  2  6  5 18  9  1 16 11  8 12 13  3 15 17 14 19 32  4 35 39
#  23 21 27 30 24 25 28 31 22 29 26 50 42 37]
# Количество уникальных значений столбца total_images: 38
#
# Уникальные значения столбца last_price: [13000000  3350000  5196000 ...  6151120 21400000 11475000]
# Количество уникальных значений столбца last_price: 2978
#
# Уникальные значения столбца total_area: [108.    40.4   56.   ...  66.86 133.81  76.75]
# Количество уникальных значений столбца total_area: 2182
#
# Уникальные значения столбца first_day_exposition: ['2019-03-07T00:00:00.000000000' '2018-12-04T00:00:00.000000000'
#  '2015-08-20T00:00:00.000000000' ... '2014-12-29T00:00:00.000000000'
#  '2016-09-12T00:00:00.000000000' '2015-07-19T00:00:00.000000000']
# Количество уникальных значений столбца first_day_exposition: 1491
#
# Уникальные значения столбца rooms: [ 3  1  2  4  5  6  0  7 11  8 14 10 15  9 19 16 12]
# ...

# %% [markdown]
# `totla_images` - присутствуют нулевые значения. Фотографии могли не загрузиться из-за технической ошибки. Либо продавец по какой-либо причине сам не стал их добавлять.
#
# `rooms` - встречаются нулевые значения. Это допустимо для студий и квартир со свободной планировкой. Проверим это ниже. Также встречаются значения от **20** и более. Существование таких квартир возможно, но, скорее всего, их должно быть немного по сравнению с остальными. Также проверим ниже.
#
# `ceiling_height` - встречаются подозрительные значениями высоты потолков от **20** до **100** метров. Обработаем их.
#
# `kitchen_area` - встречаются значения с большим количеством знаков после запятой. Пока оставим без изменений. Эти значения не должны оказать сильного влияния на дальнейшее исследование.
#
# `locality_name` - наблюдаем неявные дубликаты, обработаем их позже.

# %%
# выведем на экран строки, в которых значение высоты потолков более 20 метров
data[data['ceiling_height'] >= 20]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17     3600000        55.2           2018-07-12      2
# 3148             14     2900000        75.0           2018-11-12      3
# 4643              0     4300000        45.0           2018-02-01      2
# 4876              7     3000000        25.0           2017-09-27      0
# 5076              0     3850000        30.5           2018-10-03      1
# 5246              0     2500000        54.0           2017-10-13      2
# 5669              4     4400000        50.0           2017-08-08      2
# 5807             17     8150000        80.0           2019-01-09      2
# 6246              6     3300000        44.4           2019-03-25      2
# 9379              5     3950000        42.0           2017-03-26      3
# 10773             8     3800000        58.0           2017-10-13      2
# 11285             0     1950000        37.0           2019-03-20      1
# ...

# %% [markdown]
# **23** строки содежат аномальные значения высоты потолков.
# Вероятнее всего, продавцы допустили ошибку при заполнении данного поля и забыли поставить запятую.
# Приведем эти значения к более правдоподобным.

# %%
# создадим переменную, хранящую индексы строк с аномальными значениями высоты потолков
ceiling_height_wrong_values = data.index [data['ceiling_height'] >= 20]

# изменим аномальные значения, поделив их на 10
data.loc[data['ceiling_height'] >= 20, 'ceiling_height'] = data['ceiling_height'] / 10
        
# проверим 
data.loc[ceiling_height_wrong_values, 'ceiling_height']
# Out:
# 355       2.50
# 3148      3.20
# 4643      2.50
# 4876      2.70
# 5076      2.40
# 5246      2.70
# 5669      2.60
# 5807      2.70
# 6246      2.50
# 9379      2.50
# 10773     2.70
# 11285     2.50
# 14382     2.50
# 17496     2.00
# 17857     2.70
# 18545     2.50
# 20478     2.70
# 20507     2.26
# 21377     2.75
# 21824     2.70
# 22336     3.20
# 22869    10.00
# 22938     2.70
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Очень красиво изучены выбросы 😃
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Спасибо за высокую оценку! 😊
#
# </div>

# %% [markdown]
# Аномальные значения в столбце `ceiling_height` приведены к правдоподобным.

# %%
# посчитаем количество квартир с пятью и более комнатами
print(data[data['rooms'] >= 5]['rooms'].count())

# посчитаем долю таких квартир от общего количества
((data[data['rooms'] >= 5]['rooms'].count()) / len(data['rooms'])*100).round(1)
# Out:
# 521
# 2.2

# %% [markdown]
# **521** квартира с количеством комнат **5** и более, что составляет **2.2%** от всех квартир.
# Выглядит правдоподобно.

# %%
# посчитаем количество нулевых значений в 'rooms'
data[data['rooms'] == 0]['rooms'].count()
# Out:
# 197

# %%
# посчитаем количество нулевых значений в 'rooms' для студий и квартир со свободной планировкой
data[(data['rooms'] == 0) & ((data['studio']==True) | (data['open_plan']==True))]['rooms'].count()
# Out:
# 197

# %% [markdown]
# Все **197** квартир с нулевым значением комнат относятся к студяим либо к квартирам со свободной планировкой.
# Такая ситуация логична. Аномалии отсутствуют.
#
# ---

# %% [markdown]
# Изучим подробнее уникальные значения в столбце `locality_name` и проверим на неявные дубликаты

# %%
# с помощью цикла создадим список уникальных значений столбца 'locality_name' и выведем его на экран в виде столбца
unique_values = [] 
for i in data['locality_name']: 
    if i not in unique_values: 
        unique_values.append(i) 
        
print("Количество уникальных значений столбца 'locality_name':", len(data['locality_name'].unique()))
print("Уникальные значения столбца 'locality_name':\n")
for i in unique_values: 
    print(i)
# Out:
# Количество уникальных значений столбца 'locality_name': 365
# Уникальные значения столбца 'locality_name':
#
# Санкт-Петербург
# посёлок Шушары
# городской посёлок Янино-1
# посёлок Парголово
# посёлок Мурино
# Ломоносов
# Сертолово
# Петергоф
# Пушкин
# деревня Кудрово
# Коммунар
# Колпино
# поселок городского типа Красный Бор
# Гатчина
# поселок Мурино
# деревня Фёдоровское
# Выборг
# Кронштадт
# Кировск
# деревня Новое Девяткино
# посёлок Металлострой
# посёлок городского типа Лебяжье
# посёлок городского типа Сиверский
# поселок Молодцово
# поселок городского типа Кузьмоловский
# садовое товарищество Новая Ропша
# Павловск
# деревня Пикколово
# Всеволожск
# Волхов
# Кингисепп
# Приозерск
# Сестрорецк
# деревня Куттузи
# посёлок Аннино
# поселок городского типа Ефимовский
# посёлок Плодовое
# деревня Заклинье
# поселок Торковичи
# поселок Первомайское
# Красное Село
# посёлок Понтонный
# Сясьстрой
# деревня Старая
# деревня Лесколово
# посёлок Новый Свет
# Сланцы
# село Путилово
# ...

# %% [markdown]
# В данных встречаются подстроки `поселок`, `посёлок`, `поселок городского типа`, `городской поселок`, `поселок при железнодорожной станции`, `поселок станции`, `поселок имени`, `село`, `деревня`, `садоводческое некоммерческое товарищество`, `садовое товарищество`.
#
# `село` - их очень мало и, хоть и некоторые названия пересекаются с посёлками, оставим их без изменений. Есть вероятность, что это могут оказаться разные населённые пункты с одинаковыми названиями.
#
# `посёлок`, `поселок`, `поселок городского типа`, `городской поселок` - приведём эти подстроки к единому значению `поселок` и затем удалим обозначение типа населённого пункта, оставив только название.
#
# `деревня` - удалим обозначение типа населённого пункта, оставив только название.
#
# `поселок при железнодорожной станции`, `поселок станции` - приведём эти подстроки к единому значению `посёлок станции` и сохраним.
#
# `поселок имени` - переименуем в `посёлок имени` и сохраним.
#
# `садоводческое некоммерческое товарищество`, `садовое товарищество` - оставим без изменений.

# %%
# цепочкой методов replace() избавляемся от неявных дубликатов
data['locality_name'] = (
    data['locality_name']
    .str.replace('посёлок','поселок') # меняем 'ё' на 'е' во всех 'посёлках'
    .str.replace('городского типа ','') # ПГТ преобразуем в 'поселки'
    .str.replace('городской ','') # 'городские поселки' преобразуем просто в 'поселки'
    .str.replace('деревня ','') # всем деревням оставляем только их названия
    .str.replace('коттеджный поселок', 'коттеджный посёлок') # снова меняем 'е' на 'ё', чтобы далее не потерять 
    .str.replace('поселок станции', 'посёлок станции') # снова меняем 'е' на 'ё', чтобы далее не потерять 
    .str.replace('поселок при железнодорожной станции Вещево', 'посёлок станции Вещево') 
    # снова меняем 'е' на 'ё', чтобы далее не потерять, и приводим к единому значению
    .str.replace('поселок при железнодорожной станции Приветнинское', 'посёлок станции Приветнинское')
    # снова меняем 'е' на 'ё', чтобы далее не потерять, и приводим к единому значению
    .str.replace('поселок имени', 'посёлок имени') # снова меняем 'е' на 'ё', чтобы далее не потерять
    .str.replace('поселок Жилпоселок','Жилпосёлок') # снова меняем 'е' на 'ё', чтобы далее не потерять
    .str.replace('поселок ','') # удаляем все подстроки 'поселок', оставив только названия населённых пунктов
)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что тобою было замечено разное написание слова «посёлок» и было принято решение это исправить 😃
#
# </div>

# %%
# выведем на экран обновленные уникальные значения столбца 'locality_name'
# и проверим на наличие ошибок
set(data['locality_name'].unique())
# Out:
# {nan,
#  'Агалатово',
#  'Александровская',
#  'Алексеевка',
#  'Аннино',
#  'Аро',
#  'Барышево',
#  'Батово',
#  'Бегуницы',
#  'Белогорка',
#  'Белоостров',
#  'Бокситогорск',
#  'Большая Вруда',
#  'Большая Ижора',
#  'Большая Пустомержа',
#  'Большие Колпаны',
#  'Большое Рейзино',
#  'Большой Сабск',
#  'Бор',
#  'Борисова Грива',
#  'Бугры',
#  'Будогощь',
#  'Ваганово',
#  'Важины',
#  'Вартемяги',
#  'Вахнова Кара',
#  'Виллози',
#  'Вознесенье',
#  'Возрождение',
#  'Войсковицы',
#  'Войскорово',
#  'Володарское',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Вырица',
#  'Выскатка',
#  'Высокоключевой',
#  'Высоцк',
#  'Гаврилово',
#  'Гарболово',
#  'Гатчина',
#  'Гладкое',
#  'Глажево',
#  'Глебычево',
#  'Глинка',
#  'Гончарово',
#  'Горбунки',
#  'Гостилицы',
#  'Громово',
#  'Дзержинского',
#  'Дружная Горка',
#  'Дружноселье',
#  'Дубровка',
#  'Елизаветино',
#  'Ефимовский',
#  'Жилгородок',
#  'Жилпосёлок',
#  'Житково',
#  'Заводской',
# ...

# %% [markdown]
# Ошибок не обнаружено.

# %%
# теперь проверим результат проделанной работы и выведем на экран новое количество уникальных значений 'locality_name'
len(data['locality_name'].unique())
# Out:
# 312

# %% [markdown]
# Удалось избавиться от **53** неявных дубликатов в столбце `locality_name` !
#
# Названия большинства населённых пунктов выглядят лаконично и понятно.

# %% [markdown]
# ***Вывод по поиску и обработке дубликатов:***
#
# ***Явные дубликаты в датасете обнаружены не были. То есть можно утверждать, что все представленные объявления являются уникальными.***
#
# ***В процессе изучения уникальных значений столбцов датасета были выявлены аномальные значения и неявные дубликаты:***
#
# ***1. В столбце `totla_images` (количество фотографий) были обнаружены нулевые значения. Такая ситуация допустима, но объявления о продаже квартир без фотографий вряд ли смогут заинтересовать потенциальных покупателей.***
#
# ***2. В столбце `rooms` (количество комнат) также встречаются нулевые значения. Это допустимо для студий и квартир со свободной планировкой. Небольшое количество квартир имеют от 20 комнат и более (2.2% от общего количества).***
#
# ***3. В столбце `ceiling_height` (высота потолков) были обнаружены аномальные значения высоты потолков (от 20 до 100 метров). Возможно, сыграл человеческий фактор, и продавцы просто опечатались. Было принято решение обработать аномально большие значения перемещением запятой на один знак влево.***
#
# ***4. В столбце `kitchen_area` (площадь кухни) были обнаружены значения с большим количеством знаков после запятой. Ввиду того, что данный факт не окажет сильного влияния на исследование, было решено оставаить эти значения без изменений.***
#
# ***5. В столбце `locality_name` (название населённого пункта) были обнаружены неявные дубликаты, связанные с различными обозначениями одних и тех же локаций ("Любань" и "поселок Любань", "поселок Бугры" и "посёлок Бугры", и т.д.). Поэтому назавния насёленных пунктов были упрощены и приведены к лаконичному понятному виду, что позволило сократить количество неявных дубликатов с 365 до 312.***
#
# ---

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Очень качественно подготовлены данные для дальнейшего исследования, но нет промежуточных выводов по всей предобработке.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Добавил промежуточные и общие выводы на всех шагах предобработки. Выделил их ***жирным курсивом***.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Молодец, проведено мини исследование, пропуски заполнены с минимальными потерями в информации 👍
#
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# - цена одного квадратного метра (`price_per_square_meter`)
# - день публикации объявления (0 - понедельник, 1 - вторник и т.д.) (`publication_weekday`)
# - месяц публикации объявления (`publication_month`)
# - год публикации объявления (`publication_year`)
# - тип этажа квартиры (значения — «первый», «последний», «другой») (`floor_type`)
# - расстояние в км до центра города (`city_centers_nearest_km`)

# %%
# добавляем столбец, отражающий цену за один квадратный метр и округляем до двух знаков после запятой
data['price_per_square_meter'] = (data['last_price'] / data['total_area']).round(2)

# проверяем
data['price_per_square_meter'].head()
# Out:
# 0    120370.37
# 1     82920.79
# 2     92785.71
# 3    408176.10
# 4    100000.00
# Name: price_per_square_meter, dtype: float64

# %%
# добавляем столбец, отражающий день недели публикации объявления (0 — понедельник, 1 — вторник и так далее)
data['publication_weekday'] = pd.DatetimeIndex(data['first_day_exposition']).weekday

# проверяем
data[['publication_weekday', 'first_day_exposition']].head()
# Out:
#    publication_weekday first_day_exposition
# 0                    3           2019-03-07
# 1                    1           2018-12-04
# 2                    3           2015-08-20
# 3                    4           2015-07-24
# 4                    1           2018-06-19

# %%
# добавляем столбец, отражающий месяц недели публикации объявления 
data['publication_month'] = pd.DatetimeIndex(data['first_day_exposition']).month

# проверяем
data[['publication_month', 'first_day_exposition']].head()
# Out:
#    publication_month first_day_exposition
# 0                  3           2019-03-07
# 1                 12           2018-12-04
# 2                  8           2015-08-20
# 3                  7           2015-07-24
# 4                  6           2018-06-19

# %%
# добавляем столбец, отражающий год публикации объявления
data['publication_year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# проверяем
data[['publication_year', 'first_day_exposition']].head()
# Out:
#    publication_year first_day_exposition
# 0              2019           2019-03-07
# 1              2018           2018-12-04
# 2              2015           2015-08-20
# 3              2015           2015-07-24
# 4              2018           2018-06-19

# %% [markdown]
# ---
# Вернёмся к проверке взаимосвязи между пропусками в столбцах с картографическими данными.

# %%
# изучим распределение пропусков в данных столбцах по годам
print('parks_nearest \n', data[data['parks_nearest'].isna()].groupby('publication_year')['rooms'].count())
print()
print('ponds_nearest \n', data[data['ponds_nearest'].isna()].groupby('publication_year')['rooms'].count())
print()
print('airports_nearest \n', data[data['airports_nearest'].isna()].groupby('publication_year')['rooms'].count())
print()
print('city_centers_nearest \n', data[data['city_centers_nearest'].isna()].groupby('publication_year')['rooms'].count())
print()
print('ponds_around_3000 \n', data[data['ponds_around_3000'].isna()].groupby('publication_year')['rooms'].count())
print()
print('parks_around_3000 \n', data[data['parks_around_3000'].isna()].groupby('publication_year')['rooms'].count())
# Out:
# parks_nearest
#  publication_year
# 2014      68
# 2015     719
# 2016    1777
# 2017    5329
# 2018    5823
# 2019    1904
# Name: rooms, dtype: int64
#
# ponds_nearest
#  publication_year
# 2014      70
# 2015     626
# 2016    1694
# 2017    4969
# 2018    5426
# 2019    1804
# Name: rooms, dtype: int64
#
# airports_nearest
#  publication_year
# 2014      22
# 2015     213
# 2016     596
# 2017    1769
# 2018    2267
# 2019     675
# Name: rooms, dtype: int64
#
# city_centers_nearest
#  publication_year
# 2014      22
# 2015     211
# 2016     593
# 2017    1759
# 2018    2258
# 2019     676
# Name: rooms, dtype: int64
#
# ponds_around_3000
#  publication_year
# 2014      22
# 2015     211
# 2016     593
# 2017    1759
# 2018    2258
# 2019     675
# Name: rooms, dtype: int64
#
# parks_around_3000
#  publication_year
# 2014      22
# 2015     211
# 2016     593
# 2017    1759
# 2018    2258
# 2019     675
# Name: rooms, dtype: int64

# %% [markdown]
# Наблюдаем схожесть количества пропусков в этих столбцах по определённым годам.
# С 2014 года по 2018 год чисо сбоев при выгрузке картографических данных росло.
# А в 2019 году удалось достигнуть ощутимых успехов в решении данной проблемы.
#
# ---

# %%
# добавляем столбец, отражающий тип этажа квартиры (значения: «первый», «последний», «другой»)
# создаём функцию для категоризации квартир в зависимости от этажа
def floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
# добавляем столбец с категорией этажа квартиры
data['floor_type'] = data.apply(floor_type, axis=1)

# проверим результат работы функции
data[['floor_type', 'floor', 'floors_total']].head(20)
# Out:
#    floor_type  floor  floors_total
# 0      другой      8            16
# 1      первый      1            11
# 2      другой      4             5
# 3      другой      9            14
# 4      другой     13            14
# 5      другой      5            12
# 6      другой      6            26
# 7      другой     22            24
# 8      другой     26            27
# 9      другой      7             9
# 10     другой      3            12
# 11     другой      4             5
# 12  последний      5             5
# 13  последний      5             5
# 14     первый      1             6
# 15     другой      5            14
# 16     первый      1             5
# 17     другой      7            17
# 18     другой      2             5
# 19     другой      8            16

# %% [markdown]
# Категоризация квартир по типу этажа прошла корректно.

# %%
# добавляем столбец, отражающий расстояние до центра города в километрах 
# переведём из м в км и округлим до ближайших целых значений
data['city_centers_nearest_km'] = round(data['city_centers_nearest'] / 1000)

# проверяем
data[['city_centers_nearest', 'city_centers_nearest_km']].head()
# Out:
#    city_centers_nearest  city_centers_nearest_km
# 0               16028.0                     16.0
# 1               18603.0                     19.0
# 2               13933.0                     14.0
# 3                6800.0                      7.0
# 4                8098.0                      8.0

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, корректно созданы дополнительные столбцы с необходимыми метриками.
#
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# **Изучим отдельные параметры квартир, проверим на наличие выбросов и построим подходящие графики для каждого параметра**
#
# ---

# %% [markdown]
# **Общая площадь**

# %%
# изучим распределение данных по столбцу 'total_area'
print('Распределение данных по общей площади \n')
print(data['total_area'].describe())

# построим гистограмму для общей площади квартир
data['total_area'].plot(
    kind='hist', 
    bins=25,
    range=(0, 250),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='coral')
plt.title('Общая площадь')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по общей площади
#
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
# построим диаграмму размаха для 'total_area'
data.boxplot(column=['total_area'], figsize=(10,7), grid=True)
plt.ylabel('Общая площадь, кв. м')
plt.ylim(0, 150)
plt.show()

# %% [markdown]
# Значения больше **120** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_total_area = data.query('total_area < 120')

# посмотрим, сколько процентов от данных мы потеряем
total_area_blowout = round(
    ((len(data['total_area']) - len(good_total_area['total_area'])) / len(data['total_area'])*100), 2)
print(f'Отфильтрованные выбросы "total_area": {total_area_blowout}%')
# Out:
# Отфильтрованные выбросы "total_area": 4.63%

# %% [markdown]
# ***Процент отфильтрованных данных равен 4.63. Исключение выбросов в данном случае целесообразно.***

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# В таких ситуациях box-plot лучше строить с ylim и гистограмму с range, для наглядности.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# В первичные гистограммы и диаграммы размаха по всем рассматриваемым параметрам включил **range** и **ylim** для большей наглядности.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Рад, что ты используешь ylim и range, так понятнее. 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Перед отбросом выбросов очень важно в процентах оценить, сколько мы теряем, должно быть не более 10%.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Перед построением финальных гистограмм по всем параметрам оценил целесообразность исключения выбросов.
#
# В случае, если процент потерянных данных составлял менее 10%, отбрасывал выбросы и строил гистограммы по отфильтрованным данным.
#
# В целом, я и так оценивал процент потерь. Но делал это не перед оформлением финальной гистограммы, а уже после, перед выводами. Поэтому переместил оценку выше. Согласен, если отфильтровать слишком много значений, пусть даже и выбивающихся, окончательный результат может выйти искажённым.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# На самом деле чем больше данных остается, тем лучше, поэтому лучше убирать именно выбивающиеся значения, если их много, то значит у нас данные размазаны, а эти значения нормальные(а не выбивающиеся).
#
# Я в работе пользуюсь методом [quantile](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html) и убираю с обеих сторон данные, которые выходят за 1-3%(то есть менее 0.03 и более 0.97 перцентиля), если сделать такое преобразование по нескольким колонкам, то как раз и получится около 10%. Ниже показал.
#
# </div>

# %%
# Код ревьюера

low_percentele = 0.01
hihg_percentele = 0.99

last_price_low = data['last_price'].quantile(low_percentele)
last_price_high = data['last_price'].quantile(hihg_percentele)

print(f'Нижняя граница last_price {last_price_low}')
print(f'Верхняя граница last_price {last_price_high}')

print(
    'Процент отброшенных значений = ',
    round(
        100 - len(data.query('@last_price_low <= last_price <= @last_price_high'))
        / len(data['last_price']) * 100,
        2
    ),
    '%'
)
# Out:
# Нижняя граница last_price 1000000.0
# Верхняя граница last_price 36000000.0
# Процент отброшенных значений =  1.95 %

# %%
# изучим распределение данных по отфильтрованному столбцу 'total_area'
print('Распределение данных по общей площади \n')
print(good_total_area['total_area'].describe())

# построим гистограмму для общей площади квартир
good_total_area['total_area'].plot(
    kind='hist', 
    bins=25,
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='coral')
plt.title('Общая площадь')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по общей площади
#
# count    22601.000000
# mean        54.757439
# std         19.945249
# min         12.000000
# 25%         39.500000
# 50%         50.400000
# 75%         66.000000
# max        119.800000
# Name: total_area, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **55**, медиана - **50**
# Чаще всего встречаются квартиры с общей площадью от **30** до **60** кв.м
# Площадь около **45** кв.м - самый популярный вариант
# Далее идет категория от **60** до **100** кв.м
# Реже всего встречаются квартиры общей площадью менее **25** и более **100** кв.м
#
# ---

# %% [markdown]
# **Жилая площадь**

# %%
# изучим распределение данных по столбцу 'living_area'
print('Распределение данных по жилой площади \n')
print(data['living_area'].describe())

# построим гистограмму для жилой площади квартир
data['living_area'].plot(
    kind='hist', 
    bins=50,
    range=(0, 150),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='mediumseagreen')
plt.title('Жилая площадь')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по жилой площади
#
# count    23699.000000
# mean        34.562480
# std         22.326965
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.100000
# max        409.700000
# Name: living_area, dtype: float64

# %%
# построим диаграмму размаха для 'living_area'
data.boxplot(column=['living_area'], figsize=(10,7), grid=True)
plt.ylabel('Жилая площадь, кв. м')
plt.ylim(0, 150)
plt.show()

# %% [markdown]
# Значения больше **80** - выбросы.
# ***Min*** равно **2**. Неправдоподобно.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_living_area = data.query('2 < living_area < 80')

# посмотрим, сколько процентов от данных мы потеряем
living_area_blowout = round(
    ((len(data['living_area']) - len(good_living_area['living_area'])) / len(data['living_area'])*100), 2)
print(f'Отфильтрованные выбросы "living_area": {living_area_blowout}%')
# Out:
# Отфильтрованные выбросы "living_area": 3.37%

# %% [markdown]
# ***Процент отфильтрованных данных равен 3.37. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'living_area'
print('Распределение данных по жилой площади \n')
print(good_living_area['living_area'].describe())

# построим гистограмму для жилой площади квартир
good_living_area['living_area'].plot(
    kind='hist', 
    bins=15, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='mediumseagreen')
plt.title('Жилая площадь')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по жилой площади
#
# count    22900.000000
# mean        31.693634
# std         14.031383
# min          3.000000
# 25%         18.700000
# 50%         30.000000
# 75%         40.900000
# max         79.740000
# Name: living_area, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **31**, медиана - **30**
# Чаще всего встречаются квартиры с жилой площадью  от **15** до **40** кв.м
# Площадь около **15** кв.м - самый популярный вариант
# Далее идет категория от **40** до **55** кв.м
# Реже всего встречаются квартиры с жилой площадью **10** кв.м и менее, и более **60** кв.м
#
# ---

# %% [markdown]
# **Площадь кухни**

# %%
# изучим распределение данных по столбцу 'kitchen_area'
print('Распределение данных по площади кухни \n')
print(data['kitchen_area'].describe())

# построим гистограмму для площади кухонь
data['kitchen_area'].plot(
    kind='hist', 
    bins=25,
    range=(0, 60),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='slategrey')
plt.title('Площадь кухни')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по площади кухни
#
# count    23699.000000
# mean        10.520363
# std          6.142305
# min          0.000000
# 25%          7.000000
# 50%          9.010000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
# построим диаграмму размаха для 'kitchen_area'
data.boxplot(column=['kitchen_area'], figsize=(10,7), grid=True)
plt.ylabel('Площадь кухни, кв. м')
plt.ylim(0, 60)
plt.show()

# %% [markdown]
# Значения больше **25** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_kitchen_area = data.query('kitchen_area <= 25')

# посмотрим, сколько процентов от данных мы потеряем
kitchen_area_blowout = round(
    ((len(data['kitchen_area']) - len(good_kitchen_area['kitchen_area'])) / len(data['kitchen_area'])*100), 2)
print(f'Отфильтрованные выбросы "kitchen_area": {kitchen_area_blowout}%')
# Out:
# Отфильтрованные выбросы "kitchen_area": 2.68%

# %% [markdown]
# ***Процент отфильтрованных данных равен 2.68. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'kitchen_area'
print('Распределение данных по площади кухни \n')
print(good_kitchen_area['kitchen_area'].describe())

# построим гистограмму для площади кухонь
good_kitchen_area['kitchen_area'].plot(
    kind='hist', 
    bins=25,  
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='slategrey')
plt.title('Площадь кухни')
plt.xlabel('Площадь, кв. м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по площади кухни
#
# count    23064.000000
# mean         9.802016
# std          3.899258
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.600000
# max         25.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Красивое построение и выводы правильные, молодец 😃
#
# </div>

# %% [markdown]
# **Вывод**
# Среднее значение - **9.8**, медиана - **9**
# Чаще всего встречаются квартиры с площадью кухни от **5** до **12** кв.м
# Площадь кухни около **8** кв.м - самый популярный вариант
# Далее идет категория от **12** до **15** кв.м
# Реже всего встречаются квартиры площадью кухни менее **5** и более **20** кв.м
# Небольшой "всплеск" квартир с **нулевой** площадью кухни связан со студиями и квартирами со свободной планировкой.
#
# ---

# %% [markdown]
# **Цена объекта**

# %%
# изучим распределение данных по столбцу 'last_price'
print('Распределение данных по цене объекта \n')
print(round(data['last_price'].describe()))

# построим гистограмму для цены объекта
data['last_price'].plot(
    kind='hist', 
    bins=75,
    range=(0, 30000000),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='darkgoldenrod')
plt.title('Цена объекта')
plt.xlabel('Цена (10 млн)')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по цене объекта
#
# count        23699.0
# mean       6541549.0
# std       10887013.0
# min          12190.0
# 25%        3400000.0
# 50%        4650000.0
# 75%        6800000.0
# max      763000000.0
# Name: last_price, dtype: float64

# %%
# построим диаграмму размаха для 'last_price'
data.boxplot(column=['last_price'], figsize=(10,7), grid=True)
plt.ylabel('Цена объекта (10 млн)')
plt.ylim(0, 50000000)
plt.show()

# %% [markdown]
# Значения больше **20 млн** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_last_price = data.query('last_price < 20000000')

# посмотрим, сколько процентов от данных мы потеряем
last_price_blowout = round(
    ((len(data['last_price']) - len(good_last_price['last_price'])) / len(data['last_price'])*100), 2)
print(f'Отфильтрованные выбросы "last_price": {last_price_blowout}%')
# Out:
# Отфильтрованные выбросы "last_price": 3.05%

# %% [markdown]
# ***Процент отфильтрованных данных равен 3.05. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'last_price'
print('Распределение данных по цене объекта \n')
print(round(good_last_price['last_price'].describe()))

# построим гистограмму для цены объекта
good_last_price['last_price'].plot(
    kind='hist', 
    bins=50,
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='darkgoldenrod')
plt.title('Цена объекта')
plt.xlabel('Цена (10 млн)')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по цене объекта
#
# count       22976.0
# mean      5413456.0
# std       3198216.0
# min         12190.0
# 25%       3400000.0
# 50%       4550000.0
# 75%       6500000.0
# max      19999000.0
# Name: last_price, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **5413456**, медиана - **4550000**
# Чаще всего встречаются квартиры с ценой от **2.3** до **6** млн
# Цена около **3.75** млн - самый популярный вариант
# Далее идет категория от **6** до **7.6** млн
# Реже всего встречаются квартиры с ценой менее **1** млн и более **10** млн
#
# ---

# %% [markdown]
# **Количество комнат**

# %%
# изучим распределение данных по столбцу 'rooms'
print('Распределение данных по количеству комнат \n')
print(data['rooms'].describe())

# построим гистограмму для количества комнат
data['rooms'].plot(
    kind='hist', 
    bins=10,
    range=(0, 15),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=3, 
    color='plum')
plt.title('Количество комнат')
plt.xlabel('Комнаты')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по количеству комнат
#
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
# построим диаграмму размаха для 'rooms'
data.boxplot(column=['rooms'], figsize=(10,7), grid=True)
plt.ylabel('Количество комнат')
plt.ylim(0, 15)
plt.show()

# %% [markdown]
# Значения больше **7** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_rooms = data.query('rooms <= 7')

# посмотрим, сколько процентов от данных мы потеряем
rooms_blowout = round(
    ((len(data['rooms']) - len(good_rooms['rooms'])) / len(data['rooms'])*100), 2)
print(f'Отфильтрованные выбросы "rooms": {rooms_blowout}%')
# Out:
# Отфильтрованные выбросы "rooms": 0.13%

# %% [markdown]
# ***Процент отфильтрованных данных равен 0.13. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'rooms'
print('Распределение данных по количеству комнат \n')
print(good_rooms['rooms'].describe())

# построим гистограмму для количества комнат
good_rooms['rooms'].plot(
    kind='hist', 
    bins=8, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=3, 
    color='plum')
plt.title('Количество комнат')
plt.xlabel('Комнаты')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по количеству комнат
#
# count    23668.000000
# mean         2.060250
# std          1.035396
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          7.000000
# Name: rooms, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение и медиана схожи и равны **2**
# Чаще всего встречаются квартиры с **1-2** комнатами
# Далее идет категория квартир с **3** комнатами
# Реже всего встречаются квартиры с **4 и более** комнатами
# Квартиры с **0** комнат - это студии и квартиры со свободной планировкой
#
# ---

# %% [markdown]
# **Высота потолков**

# %%
# изучим распределение данных по столбцу 'ceiling_height'
print('Распределение данных по высоте потолков \n')
print(data['ceiling_height'].describe())

# построим гистограмму для высоты потолков
data['ceiling_height'].plot(
    kind='hist', 
    bins=30,
    range=(1, 5),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=3, 
    color='y')
plt.title('Высота потолков')
plt.xlabel('Потолки, м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по высоте потолков
#
# count    23699.000000
# mean         2.698721
# std          0.253208
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %%
# построим диаграмму размаха для 'ceiling_height'
data.boxplot(column=['ceiling_height'], figsize=(10,7), grid=True)
plt.ylabel('Высота потолков')
plt.ylim(2, 4)
plt.show()

# %% [markdown]
# Значения больше **3.1** и меньше **2.4** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_ceiling_height = data.query('2.4 < ceiling_height < 3.1')

# посмотрим, сколько процентов от данных мы потеряем
ceiling_height_blowout = round(
    ((len(data['ceiling_height']) - len(good_ceiling_height['ceiling_height'])) / len(data['ceiling_height'])*100), 2)
print(f'Отфильтрованные выбросы "ceiling_height": {ceiling_height_blowout}%')
# Out:
# Отфильтрованные выбросы "ceiling_height": 6.1%

# %% [markdown]
# ***Процент отфильтрованных данных равен 6.1. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по столбцу отфильтрованному 'ceiling_height'
print('Распределение данных по высоте потолков \n')
print(good_ceiling_height['ceiling_height'].describe())

# построим гистограмму для высоты потолков
good_ceiling_height['ceiling_height'].plot(
    kind='hist', 
    bins=15,  
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=3, 
    color='y')
plt.title('Высота потолков')
plt.xlabel('Потолки, м')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по высоте потолков
#
# count    22253.000000
# mean         2.655051
# std          0.119398
# min          2.450000
# 25%          2.600000
# 50%          2.650000
# 75%          2.650000
# max          3.090000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **2.65**, медиана - **2.65**
# Чаще всего встречаются квартиры с высотой потолков от **2.65** метров
# Далее идут **2.5**, **2.6** и **2.7** метров
# Квартиры с высотой потолков от **2.7** и более встречаются редко
#
# ---

# %% [markdown]
# **Этаж квартиры**

# %%
# изучим распределение данных по столбцу 'floor'
print('Распределение данных по этажу \n')
print(data['floor'].describe())

# построим гистограмму для этажей
data['floor'].plot(
    kind='hist', 
    bins=10,
    range=(0, 25),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=3, 
    color='springgreen')
plt.title('Этаж квартиры')
plt.xlabel('Этаж')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по этажу
#
# count    23699.000000
# mean         5.892358
# std          4.885249
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %%
# построим диаграмму размаха для 'floor'
data.boxplot(column=['floor'], figsize=(10,7), grid=True)
plt.ylabel('Этаж квартиры')
plt.ylim(0, 30)
plt.show()

# %% [markdown]
# Значения больше **18** - выбросы. Отфильтруем их.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_floor = data.query('floor < 18')

# посмотрим, сколько процентов от данных мы потеряем
floor_blowout = round(
    ((len(data['floor']) - len(good_floor['floor'])) / len(data['floor'])*100), 2)
print(f'Отфильтрованные выбросы "floor": {floor_blowout}%')
# Out:
# Отфильтрованные выбросы "floor": 3.89%

# %% [markdown]
# ***Процент отфильтрованных данных равен 3.89. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'floor'
print('Распределение данных по этажу \n')
print(good_floor['floor'].describe())

# построим гистограмму для этажей
good_floor['floor'].plot(
    kind='hist', 
    bins=10, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=3, 
    color='springgreen')
plt.title('Этаж квартиры')
plt.xlabel('Этаж')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по этажу
#
# count    22777.000000
# mean         5.281468
# std          3.871898
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          7.000000
# max         17.000000
# Name: floor, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **5**, медиана - **4**
# Большинство квартир расположены на **1-4** этажах
# Реже встречаются квартиры на **5-6** и **10** этажах и ещё реже - выше **11** этажа
#
# ---

# %% [markdown]
# **Тип этажа квартиры («первый», «последний», «другой»)**

# %%
# изучим распределние квартир в data по типу этажа
# для этого построим круговую диаграмму

colors = ['darkseagreen', 'darksalmon', 'cornflowerblue']
explode = (0.03, 0.03, 0.03)
print(data.groupby(['floor_type'])['floor_type'].count().plot(
    kind='pie', 
    figsize=(7, 7), 
    legend=True, 
    startangle=50, 
    autopct='%1.0f%%',
    colors=colors, 
    explode=explode))
plt.ylabel(None);

# создадим сводную таблицу распределения квартир по типу этажа
floor_type_pivot = data.pivot_table(index='floor_type', values='floor', aggfunc='count')

# добавим столбец, отражающий долю каждого типа в процентах от общего количества квартир 
floor_type_pivot['floor_type_%'] = round((floor_type_pivot['floor'] / len(data['floor_type'])*100))

# переименуем столбец 'floor' в 'floor_type_count'
floor_type_pivot = floor_type_pivot.rename(columns={'floor': 'floor_type_count'})

# выведем получившуюся сводную таблицу на экран, отсортировав по убыванию доли
floor_type_pivot.sort_values(by='floor_type_%', ascending=False)
# Out:
# AxesSubplot(0.135,0.125;0.755x0.755)
#             floor_type_count  floor_type_%
# floor_type
# другой                 17446          74.0
# последний               3336          14.0
# первый                  2917          12.0

# %%
# построим график распределения этажей по типу
data['floor_type'].value_counts(ascending=False).plot.barh(
    stacked=True,
    figsize=(12, 3),
    color='darkseagreen',
    ec='black',
    grid=True)
plt.title('Распределение по типу этажа')
plt.xlabel('Квартиры')
plt.show()

# %% [markdown]
# **Вывод:**
# Четверть от всех продаваемых квартир находятся либо на первом либо на последнем этажах. Но квартир в продаже на первых этажах всё же меньше. Это может быть связано с тем, что мы рассматриваем только объявления по продаже жилой недвижимости. А довольно часто квартиры на первых этажах переводят в статус нежилых помещений и используют для коммерческих нужд. Также часть новых жилых комплексов строится с первым этажом, заранее отведённым под коммерческие помещения.
#
# Большинство продаваемых жилых объектов недвижимости в Санкт-Петербурге и пригородах расположено в диапозоне этажей между **первым** и **последним**.
#
# ---

# %% [markdown]
# **Общее количество этажей в доме**

# %%
# изучим распределение данных по столбцу 'floors_total'
print('Распределение данных по общему количеству этажей в доме \n')
print(data['floors_total'].describe())

# построим гистограмму для общего количества этажей
data['floors_total'].plot(
    kind='hist', 
    bins=50,
    range=(0, 50),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='peru')
plt.title('Общее количество этажей в доме')
plt.xlabel('Количество этажей')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по общему количеству этажей в доме
#
# count    23699.000000
# mean        10.681759
# std          6.599383
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
# построим диаграмму размаха для 'total_area'
data.boxplot(column=['floors_total'], figsize=(10,7), grid=True)
plt.ylabel('Общее количество этажей в доме')
plt.ylim(0, 40)
plt.show()

# %% [markdown]
# Значения больше **30** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_floors_total = data.query('floors_total < 30')

# посмотрим, сколько процентов от данных мы потеряем
floors_total_blowout = round(
    ((len(data['floors_total']) - len(good_floors_total['floors_total'])) / len(data['floors_total'])*100), 2)
print(f'Отфильтрованные выбросы "floors_total": {floors_total_blowout}%')
# Out:
# Отфильтрованные выбросы "floors_total": 0.14%

# %% [markdown]
# ***Процент отфильтрованных данных равен 0.14. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'floors_total'
print('Распределение данных по общему количеству этажей в доме \n')
print(good_floors_total['floors_total'].describe())

# построим гистограмму для общего количества этажей
good_floors_total['floors_total'].plot(
    kind='hist', 
    bins=15, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='peru')
plt.title('Общее количество этажей в доме')
plt.xlabel('Количество этажей')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по общему количеству этажей в доме
#
# count    23667.000000
# mean        10.647019
# std          6.533020
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         29.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **10**, медиана - **9**
# Чаще всего встречаются дома в **5** и **9-10** этажей. Видимо, речь идет о так называемых "хрущёвках" и "брежневках"
# Дома с иной этажностью встречаются гораздо реже и распределены, в целом, равномерно.
#
# ---

# %% [markdown]
# **Расстояние до центра города в метрах**

# %%
# изучим распределение данных по столбцу 'city_centers_nearest'
print('Распределение данных по расстоянию до центра города в метрах \n')
print(data['city_centers_nearest'].describe())

# построим гистограмму для расстояния до центра города в метрах
data['city_centers_nearest'].plot(
    kind='hist', 
    bins=50,
    range=(0, 60000),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='lightskyblue')
plt.title('Расстояние до центра города в метрах')
plt.xlabel('Метры')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по расстоянию до центра города в метрах
#
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %%
# построим диаграмму размаха для 'city_centers_nearest'
data.boxplot(column=['city_centers_nearest'], figsize=(10,7), grid=True)
plt.ylabel('Расстояние до центра города в метрах')
plt.ylim(0, 40000)
plt.show()

# %% [markdown]
# Значения больше **28000** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_city_centers_nearest = data.query('city_centers_nearest < 28000')

# посмотрим, сколько процентов от данных мы потеряем
c_c_n_filled_values = (data['city_centers_nearest'].isna() == False).sum() 
good_city_centers_blowout = round(
    ((c_c_n_filled_values - len(good_city_centers_nearest['city_centers_nearest'])) / c_c_n_filled_values*100), 2)
print(f'Отфильтрованные выбросы "city_centers_nearest": {good_city_centers_blowout}%')
# Out:
# Отфильтрованные выбросы "city_centers_nearest": 8.91%

# %% [markdown]
# ***Процент отфильтрованных данных равен 8.91. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'city_centers_nearest'
print('Распределение данных по расстоянию до центра города в метрах \n')
print(good_city_centers_nearest['city_centers_nearest'].describe())

# построим гистограмму для расстояния до центра города в метрах
good_city_centers_nearest['city_centers_nearest'].plot(
    kind='hist', 
    bins=20, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='lightskyblue')
plt.title('Расстояние до центра города в метрах')
plt.xlabel('Метры')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по расстоянию до центра города в метрах
#
# count    16560.000000
# mean     12132.415217
# std       5302.347418
# min        181.000000
# 25%       8500.500000
# 50%      12525.000000
# 75%      15416.250000
# max      27977.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **12** км, медиана - **12,5** км
# Большинство объектов находится от центра города на расстоянии **12-16** км
#
# ---

# %% [markdown]
# **Расстояние до ближайшего аэропорта**

# %%
# изучим распределение данных по столбцу 'airports_nearest '
print('Распределение данных по расстоянию до ближайшего аэропорта \n')
print(data['airports_nearest'].describe())

# построим гистограмму для расстояния до аэропорта
data['airports_nearest'].plot(
    kind='hist', 
    bins=50,
    range=(0, 70000),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='pink')
plt.title('Расстояние до ближайшего аэропорта')
plt.xlabel('Метры')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по расстоянию до ближайшего аэропорта
#
# count    18157.000000
# mean     28793.672193
# std      12630.880622
# min          0.000000
# 25%      18585.000000
# 50%      26726.000000
# 75%      37273.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
# построим диаграмму размаха для 'airports_nearest'
data.boxplot(column=['airports_nearest'], figsize=(10,7), grid=True)
plt.ylabel('Расстояние до ближайшего аэропорта')
plt.ylim(0, 80000)
plt.show()

# %% [markdown]
# Значения, равные **0** и больше **65000** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_airports_nearest = data.query('0 < airports_nearest < 65000')

# посмотрим, сколько процентов от данных мы потеряем
a_n_filled_values = (data['airports_nearest'].isna() == False).sum() 
good_airports_blowout = round(
    ((a_n_filled_values - len(good_airports_nearest['airports_nearest'])) / a_n_filled_values*100), 2)
print(f'Отфильтрованные выбросы "airports_nearest": {good_airports_blowout}%')
# Out:
# Отфильтрованные выбросы "airports_nearest": 0.66%

# %% [markdown]
# ***Процент отфильтрованных данных равен 0.66. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'airports_nearest '
print('Распределение данных по расстоянию до ближайшего аэропорта \n')
print(good_airports_nearest['airports_nearest'].describe())

# построим гистограмму для расстояния до аэропорта
good_airports_nearest['airports_nearest'].plot(
    kind='hist', 
    bins=11, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='pink')
plt.title('Расстояние до ближайшего аэропорта')
plt.xlabel('Метры')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по расстоянию до ближайшего аэропорта
#
# count    18038.000000
# mean     28528.965018
# std      12227.525646
# min       6450.000000
# 25%      18539.750000
# 50%      26585.000000
# 75%      36967.750000
# max      64956.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **28.5** км, медиана - **26.5** км
# Большинство объектов расположено на расстоянии **15-25** км от аэропорта
#
# ---

# %% [markdown]
# **Расстояние до ближайшего парка**

# %%
# изучим распределение данных по столбцу 'parks_nearest'
print('Распределение данных по расстоянию до ближайшего парка \n')
print(data['parks_nearest'].describe())

# построим гистограмму для расстояния до ближайшего парка
data['parks_nearest'].plot(
    kind='hist', 
    bins=50,
    range=(0, 2500),
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='yellow')
plt.title('Расстояние до ближайшего парка')
plt.xlabel('Метры')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по расстоянию до ближайшего парка
#
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
# построим диаграмму размаха для 'parks_nearest'
data.boxplot(column=['parks_nearest'], figsize=(10,7), grid=True)
plt.ylabel('Расстояние до ближайшего парка')
plt.ylim(0, 1500)
plt.show()

# %% [markdown]
# Значения больше **1100** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# создадим переменную с отфильтрованными данными
good_parks_nearest = data.query('parks_nearest < 1100')

# посмотрим, сколько процентов от данных мы потеряем
p_n_filled_values = (data['parks_nearest'].isna() == False).sum() 
parks_nearest_blowout = round(
    ((p_n_filled_values - len(good_parks_nearest['parks_nearest'])) / p_n_filled_values*100), 2)
print(f'Отфильтрованные выбросы "parks_nearest": {parks_nearest_blowout}%')
# Out:
# Отфильтрованные выбросы "parks_nearest": 3.89%

# %% [markdown]
# ***Процент отфильтрованных данных равен 3.89. Исключение выбросов в данном случае целесообразно.***

# %%
# изучим распределение данных по отфильтрованному столбцу 'parks_nearest'
print('Распределение данных по расстоянию до ближайшего парка \n')
print(good_parks_nearest['parks_nearest'].describe())

# построим гистограмму для расстояния до ближайшего парка
good_parks_nearest['parks_nearest'].plot(
    kind='hist', 
    bins=20, 
    grid=True, 
    legend=True, 
    figsize=(15,10), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='yellow')
plt.title('Расстояние до ближайшего парка')
plt.xlabel('Метры')
plt.ylabel('Квартиры')
plt.show()
# Out:
# Распределение данных по расстоянию до ближайшего парка
#
# count    7765.000000
# mean      440.466066
# std       215.943675
# min         1.000000
# 25%       281.000000
# 50%       441.000000
# 75%       592.000000
# max      1098.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# **Вывод**
# Среднее значение - **440** метров, медиана - **441** метров
# Большинство объектов расположено на расстоянии **300-600** метров от ближайшего парка
#
# ---

# %% [markdown]
# **День и месяц публикации объявления**

# %%
# построим столбчатую диаграмму для визуализации распределения объявлений по дням недели
# и отсортируем по возрастанию значений
data.groupby('publication_weekday')['rooms'].count().sort_values().plot(
    kind='bar',
    figsize=(10, 5),
    color='mediumaquamarine',
    ec='black',
    grid=True)
plt.title('День недели публикации')
plt.xlabel('Дни недели')
plt.ylabel('Объявления')
plt.show()

# %%
# создадим сводную таблицу для подсчета количества объявлений по дням недели
# и отсортируем по возрастанию значений
(data
 .pivot_table(index='publication_weekday', values='rooms', aggfunc='count')
 .rename(columns={'rooms': 'quantity'})
 .sort_values(by='quantity'))
# Out:
#                      quantity
# publication_weekday
# 6                        1699
# 5                        1936
# 0                        3612
# 2                        3974
# 4                        4000
# 1                        4183
# 3                        4295

# %% [markdown]
# **Вывод:**
# По будним дням объявления публиковались чаще, чем по выходным.
# Наибольшая активность наблюдалась по **вторникам** и **четвергам**

# %%
# построим столбчатую диаграмму для визуализации распределения объявлений по месяцам
# и отсортируем по возрастанию значений
data['publication_month'].value_counts(ascending=True).plot(
    kind='bar',
    figsize=(15, 5),
    color='sandybrown',
    ec='black',
    grid=True)
plt.title('Месяц публикации')
plt.xlabel('Месяцы')
plt.ylabel('Объявления')
plt.show()

# %%
# создадим сводную таблицу для подсчета количества объявлений по месяцам
# и отсортируем по возрастанию значений
(data
 .pivot_table(index='publication_month', values='rooms', aggfunc='count')
 .rename(columns={'rooms': 'quantity'})
 .sort_values(by='quantity'))
# Out:
#                    quantity
# publication_month
# 5                      1274
# 1                      1500
# 12                     1641
# 7                      1695
# 8                      1744
# 6                      1760
# 9                      1981
# 10                     2127
# 11                     2371
# 4                      2379
# 3                      2587
# 2                      2640

# %% [markdown]
# **Вывод:**
# В течение года наблюдаем следующие тенденции в публикации объявлений по меясцам: период наибольшей активности продавцов - конец зимы-начало весны (**февраль-март**). **Май** и **январь** - месяцы наименьшей активности.
# После майского затишья частота публицкаций немного увеличивается и держится примерно на одном уровне в течение лета. Затем плавно увеличивается от **сентября** к **ноябрю**, а в **декабре** снова снижается.
#
# Увеличение активности продавцов с начала осени и до зимы можно связать с окончанием "сезона отпусков" и желаением владельцев квартир успеть продать их до конца календарного года.
#
# ---

# %% [markdown]
# **Общий вывод по изучению отдельных параметров:**
#
# Проанализировав показатели продаваемых квартир по отдельным параметрам:
# * отфильтровали выбивающиеся значения
# * визуализировали полученные результаты
# * сделали промежуточные выводы
#
# Опираясь на данные параметры можем сделать вывод о среднестатистическом для рынка недвижимости Санкт-Петербурга и пригородов объекте продажи. Это квартира:
# * общей площадью 45-50 кв.м
# * где жилая площадь составляет от 15 до 30 кв.м
# * с площадью кухни 8-9 квм
# * общей стоимостью 3.7-4.5 млн руб.
# * состоящая из 1-2 комнат
# * с высотой потолков 2.65 м
# * находящаяся с большой долей вероятности на 1-4 этаже (и скорее ввсего не на последнем)
# * в 5-ти либо 9-ти этажном доме
# * на расстоянии примерно 14 км от центра города
# * на удалении 20 км от аэропорта
# * с парком в пределах 0.5 км
#
# И объявления о продаже этих квартир чаще всего публикуются по будним дням, а если говорить о месяцах, то пики активности продавцов приходятся на февраль-март.
#
#
# ---

# %% [markdown]
# **Задание:**
# Изучите, как быстро продавались квартиры (столбец `days_exposition`). Этот параметр показывает, сколько дней было размещено каждое объявление
# * Постройте гистограмму.
# * Посчитайте среднее и медиану.
# * В ячейке типа `markdown` опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?

# %%
# построим гистограмму для столбца 'days_exposition'
data['days_exposition'].plot(
    kind='hist', 
    bins=50, 
    grid=True, 
    legend=True, 
    figsize=(10,6), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='crimson')
plt.title('Сколько дней было размещено объявление (от публикации до снятия)')
plt.xlabel('Количество дней размещения')
plt.ylabel('Количество объявлений')
plt.show()

# %%
# посчитаем среднее значение
data['days_exposition'].mean().round(0)
# Out:
# 181.0

# %%
# посчитаем медиану
data['days_exposition'].median()
# Out:
# 95.0

# %%
# построим диаграмму размаха для 'days_exposition'
data.boxplot(column=['days_exposition'], figsize=(8,6), grid=True)
plt.ylabel('Сколько дней было размещено объявление')
plt.ylim(-50, 1000)
plt.show()

# %%
# изучим распредление данных по столбцу 'days_exposition'
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Стандартное отклонение больше среднего значения, что свидетельствует о наличии выбросов.

# %%
# определим, какие значения являются выбросами
# для этого рассчитаем межквартильный размах(IQR): Q3-Q1
# и предел нормальных значений: Q3+1,5*IQR
iqr = (232 - 45)
days_exp_max_normal_values = 232 + 1.5*iqr
round(days_exp_max_normal_values)
# Out:
# 512

# %% [markdown]
# Значения больше **512** - выбросы.
#
# Проверим, какой процент данных мы потеряем в случае фильтрации.

# %%
# Создадим переменную, хранящую отфильтрованный датасет
good_days_exposition = data.query('days_exposition < @days_exp_max_normal_values')

# посмотрим, сколько процентов от данных мы потеряем
days_exp_filled_values = (data['days_exposition'].isna() == False).sum() 
days_exposition_blowout = round(
    ((days_exp_filled_values - len(good_days_exposition['days_exposition'])) / days_exp_filled_values*100), 2)
print(f'Отфильтрованные выбросы "days_exposition": {days_exposition_blowout}%')
# Out:
# Отфильтрованные выбросы "days_exposition": 8.13%

# %% [markdown]
# ***При фильтрации потеряем 8.13% данных. Исключение выбросов в данном случае целесообразно.***

# %%
# построим гистограмму для отфильтрованного столбца 'days_exposition'
good_days_exposition['days_exposition'].plot(
    kind='hist', 
    bins=50, 
    grid=True, 
    legend=True, 
    figsize=(10,6), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='crimson')
plt.title('Сколько дней было размещено объявление (от публикации до снятия)')
plt.xlabel('Количество дней размещения')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# Для ответа на вопрос о быстрых продажах уменьшим масштаб нашего графика.

# %%
# построим гистограмму для отфильтрованного столбца 'days_exposition' в масштабе от 0 до 100 дней
good_days_exposition['days_exposition'].plot(
    kind='hist', 
    bins=50,
    range=(0, 100),
    grid=True, 
    legend=True, 
    figsize=(10,6), 
    ec='black',
    alpha=0.5,
    lw=2, 
    color='crimson')
plt.title('Сколько дней было размещено объявление (от публикации до снятия)')
plt.xlabel('Количество дней размещения')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, верно интерпретированы данные из графика и .describe() 😃
#
# </div>

# %% [markdown]
# **Вывод:**
# Среднее время продажи квартиры в Санкт-Петербурге составляет **3 месяца (181 день)**
#
# Обычно это занимает от **45** до **232** дней
#
# Быстрая продажа - **45 дней (1.5 месяца)**
#
# На **60** днях также наблюдаем пик. Возможно, это связано с тем, что продавцы, преодолевшие психологическую отметку в **45** дней, и так и не продавшие свои квартиры к этому времени, желая ускорить процесс продажи, идут на весомые уступки в окончательной цене, что позволяет им привлечь покупателей. Это касется покупателей с гибкой ценовой стратегией, не преследующих цель извлечения максимальной выгоды. Таких продавцов, скорее, больше интересует срок получения денежных средств от продажи.
#
# Необычно долгая продажа - от **232** до **512** дней
#
# ---

# %% [markdown]
# **Задание:**
# Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# Изучите, зависит ли цена от:
# * общей площади;
# * жилой площади;
# * площади кухни;
# * количества комнат;
# * тип этажа, на котором расположена квартира (первый, последний, другой);
# * даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.

# %%
# построим матрицу корреляции для выбранных параметров
data_corr = data[['last_price',
      'total_area',
      'living_area',
      'kitchen_area',
      'rooms',
      'publication_weekday',
      'publication_month',
      'publication_year']].corr()
data_corr
# Out:
#                      last_price  total_area  living_area  kitchen_area  \
# last_price             1.000000    0.653675     0.585658      0.511247
# total_area             0.653675    1.000000     0.945860      0.658821
# living_area            0.585658    0.945860     1.000000      0.501658
# kitchen_area           0.511247    0.658821     0.501658      1.000000
# rooms                  0.363343    0.758344     0.827606      0.338617
# publication_weekday    0.001550   -0.004695    -0.004148     -0.004458
# publication_month      0.002779    0.004920    -0.000371      0.001714
# publication_year      -0.043089   -0.079912    -0.072508     -0.058166
#
#                         rooms  publication_weekday  publication_month  \
# last_price           0.363343             0.001550           0.002779
# total_area           0.758344            -0.004695           0.004920
# living_area          0.827606            -0.004148          -0.000371
# ...

# %%
# на основании матрицы коррелции построим тепловую карту для лучшей визуализации
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(data_corr, annot=True, cmap='RdYlGn');

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Полный вывод, правильно посчитана и интерпретирована корреляция.
#
# </div>

# %% [markdown]
# **Вывод по матрице корреляции:**
#
# Наибольшую положительную зависимость наблюдаем между **жилой площадью и общей**.
#
# Чуть меньшая зависимость между **жилой площадью и количеством комнат**, что логично.
#
# Примерно так же **количество комнат** влияет и на **общую площадь**.
#
# Также можем сказать, что чем больше **общая площадь**, тем больше и **площадь кухни** в квартире.
#
# И чем больше **общая площадь** объекта продажи, тем и больше будет его **цена**. Последняя зависимость не такая явная, так как, как правило, с увеличением площади уменьшается цена одного квадратного метра.
#
# ---

# %%
# построим диаграму рассеяния зависимости цены от общей площади
data.plot(x='total_area', 
          y='last_price', 
          kind='scatter', 
          figsize=(10, 7), 
          alpha=0.1,
          color='forestgreen', 
          ylim=(0, 150000000))
plt.title('Зависимость общей стоимости от общей площади')
plt.xlabel('Общая площадь, кв.м')
plt.ylabel('Стоимость (100 млн)')
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# График построен верно, спасибо, что добавлена прозрачность, так нагляднее.
#
# </div>

# %% [markdown]
# Наблюдается **положительная зависимость** общей стоимости от общей площади.
#
# ---

# %%
# построим диаграму рассеяния зависимости цены от жилой площади
data.plot(x='living_area', 
          y='last_price', 
          kind='scatter', 
          figsize=(10, 7), 
          alpha=0.1, 
          color='forestgreen',
          ylim=(0, 150000000))
plt.title('Зависимость общей стоимости от жилой площади')
plt.xlabel('Жилая площадь, кв.м')
plt.ylabel('Стоимость (100 млн)')
plt.show()

# %% [markdown]
# Наблюдается **положительная зависимость** общей стоимости от жилой площади.
#
# ---

# %%
# построим диаграму рассеяния зависимости цены от площади кухни
data.plot(x='kitchen_area', 
          y='last_price', 
          kind='scatter', 
          figsize=(10, 7), 
          alpha=0.1, 
          color='forestgreen',
          ylim=(0, 150000000))
plt.title('Зависимость общей стоимости от площади кухни')
plt.xlabel('Площадь кухни, кв.м')
plt.ylabel('Стоимость (100 млн)')
plt.show()

# %% [markdown]
# Наблюдается в целом **положительная зависимость** общей стоимости от площади кухни.
# Всплеск на нулевой отметке можно связать со студиями и квартирами со свободной планировкой.
#
# ---

# %%
# построим диаграму рассеяния зависимости цены от количества комнат
data.plot(x='rooms', 
          y='last_price', 
          kind='scatter', 
          figsize=(10, 7), 
          alpha=0.1, 
          color='forestgreen',
          ylim=(0, 150000000))
plt.title('Зависимость общей стоимости от количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость (100 млн)')
plt.show()

# %% [markdown]
# Наблюдается **положительная зависимость** общей стоимости квартир от количества комнат, вплоть до того момента, пока комнат не становится больше **четырёх**. Для **пятикомнатных и более** квартир показатель общей стоимости начинает снижаться.
#
# ---

# %%
# рассчитаем медианы общей стоимости по типу этажа
# и построим столбчатую диаграмму
(data
 .groupby('floor_type')['last_price']
 .median()
 .plot(kind='bar',
       figsize=(10, 7),
       color='forestgreen'))
plt.title('Медианные значения общей стоимости по типу этажа')
plt.xlabel('Тип этажа')
plt.ylabel('Общая стоимость (1 млн руб.)')
plt.show()

# выведем получившуюся таблицу на экран
data.groupby('floor_type').agg({'last_price': 'median'})
# Out:
#             last_price
# floor_type
# другой         4850000
# первый         3900000
# последний      4300000

# %% [markdown]
# ***Будем ориентироваться на медианные значения, так как они наиболее устойчивы к выбросам.
# Видим, что, как правило, квартиры на первых этажах дешевле остальных. Однако, квартиры на последних этажах, хоть и дороже квартир на первых (возможно, из-за вида), тем не менее, дешевле квартир, находящихся в диапозоне от второго до предпоследнего этажа.***
#
# ***Жизненный опыт подсказывает, что, действительно, у покупателей не пользуются популярностью квартиры на последних этажах (независимо от этажности) из-за близости к крыше здания. Поэтому продавцы таких квартир вынуждены снижать цену.***
#
# ---

# %%
# рассчитаем медианы общей стоимости по дням недели публикации
# и построим столбчатую диаграмму
(data
 .groupby('publication_weekday')['last_price']
 .median()
 .plot(kind='bar',
       figsize=(10, 7),
       color='forestgreen'))
plt.title('Медианные значения общей стоимости по дням недели публикации')
plt.xlabel('День недели публикации')
plt.ylabel('Общая стоимость (1 млн руб.)')
plt.show()

# выведем получившуюся таблицу на экран
data.groupby('publication_weekday').agg({'last_price': 'median'})
# Out:
#                      last_price
# publication_weekday
# 0                       4650000
# 1                       4730000
# 2                       4700000
# 3                       4650000
# 4                       4585000
# 5                       4555000
# 6                       4550000

# %% [markdown]
# ***День недели публикации не влияет на общую стоимость квартир.***
#
# ---

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Считать корреляцию для категориальных данных не корректно, так как корреляция применима только к линейным зависимостям, а зависимость от категории этажа, дня недели, месяца или года не линейна, чаще всего там есть сезонность. Тут лучше просто построить столбчатую диаграмму по медианам.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Для категории этажа, дня недели, месяца и года заменил график и диаграммы рассеяния на столбчатые диаграммы сгруппированных по этим параметрам медианных значений общей стоимости.
#
# Немного обновил выводы по этим показателям.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Красивые графики, сравнение верное, выводы соответствуют графикам. 👍
#
# </div>

# %%
# рассчитаем медианы общей стоимости по месяцу публикации
# и построим столбчатую диаграмму
(data
 .groupby('publication_month')['last_price']
 .median()
 .plot(kind='bar',
       figsize=(10, 7),
       color='forestgreen'))
plt.title('Медианные значения общей стоимости по месяцу публикации')
plt.xlabel('Месяц публикации')
plt.ylabel('Общая стоимость (1 млн руб.)')
plt.show()

# выведем получившуюся таблицу на экран
data.groupby('publication_month').agg({'last_price': 'median'})
# Out:
#                    last_price
# publication_month
# 1                     4600000
# 2                     4650000
# 3                     4650000
# 4                     4800000
# 5                     4515000
# 6                     4400000
# 7                     4650000
# 8                     4570000
# 9                     4700000
# 10                    4570000
# 11                    4700000
# 12                    4700000

# %% [markdown]
# ***Месяц публикации не влияет на общую стоимость квартир.***
#
# ***Но "июньские" квартиры всё-таки немного подешевле остальных.***
#
# ---

# %%
# рассчитаем медианы общей стоимости по году публикации
# и построим столбчатую диаграмму
(data
 .groupby('publication_year')['last_price']
 .median()
 .plot(kind='bar',
       figsize=(10, 7),
       color='forestgreen'))
plt.title('Медианные значения общей стоимости по году публикации')
plt.xlabel('Год публикации')
plt.ylabel('Общая стоимость (1 млн руб.)')
plt.show()

# выведем получившуюся таблицу на экран
data.groupby('publication_year').agg({'last_price': 'median'})
# Out:
#                   last_price
# publication_year
# 2014                 7700000
# 2015                 5350000
# 2016                 4550000
# 2017                 4500000
# 2018                 4550000
# 2019                 5050000

# %% [markdown]
# ***Год публикации не влияет на общую стоимость квартир.***
#
# ***В 2014 году общая стоимость квартир была выше, но это, скорее всего, связано с конъюнктурой рынка недвижимости на тот момент.***
#
# ---

# %% [markdown]
# **Вывод:**
# Наибольеше влияние на общую (полную) стоимость объекта оказывает **общая площадь**. Чем выше площадь, тем дороже квартира.
# Также на общую стоимость влияет **тип этажа**. Очевидно, что дороже те квартиры, которые находятся между вторым и предпоследним этажами.
#
# ---

# %% [markdown]
# **Задание:**
# Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
# создадим переменную, хранящую в себе 10 населенных пунктов с наибольшим числом объявлений и выведем её на экран
largest_ad_count_locality = data['locality_name'].value_counts().head(10)
largest_ad_count_locality
# Out:
# Санкт-Петербург    15747
# Мурино               590
# Кудрово              472
# Шушары               440
# Всеволожск           398
# Пушкин               369
# Колпино              338
# Парголово            327
# Гатчина              307
# Выборг               237
# Name: locality_name, dtype: int64

# %%
# построим сводную таблицу со средней ценой одного квадратного метра в 10 населенных пунктах с наибольшим числом объявлений
price_per_square_meter_pivot = (data
 .query('locality_name in @largest_ad_count_locality.index')
 .pivot_table(index='locality_name', values='price_per_square_meter')
 .sort_values(by='price_per_square_meter', ascending=False)
 .round(2))

# добавим столбец с количеством объявлений из ранее созданной переменной
price_per_square_meter_pivot['ad_count'] = largest_ad_count_locality
price_per_square_meter_pivot
# Out:
#                  price_per_square_meter  ad_count
# locality_name
# Санкт-Петербург               114838.56     15747
# Пушкин                        103125.82       369
# Кудрово                        95324.93       472
# Парголово                      90175.91       327
# Мурино                         86087.51       590
# Шушары                         78677.36       440
# Колпино                        75424.58       338
# Гатчина                        68746.15       307
# Всеволожск                     68654.47       398
# Выборг                         58141.91       237

# %%
# построим график со средними ценами за кв.м среди 10 населенных пунктов с наибольшим числом объявлений
price_per_square_meter_pivot['price_per_square_meter'].plot(kind='barh', grid=True, color='gold', ec='black', lw=1);

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо за интересные наблюдения 😃
#
# </div>

# %% [markdown]
# **Вывод:**
# Наблюдаем самую высокую стоимость квадратного метра в самом **Санкт-Петербурге** (**114838.56 руб.**).
# Самый низкий показатель в **Выборге** (**58141.91 руб.**).
# "Тройка лидеров" по стоимости квадратного метра жилья: **Санкт-Петербург, Пушкин, Кудрово**
# "Тройка аутсайдеров": **Гатчина, Всеволожск, Выборг**
#
# ---

# %% [markdown]
# **Задание:**
# Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %%
# отфильтруем data, оставив только объекты, находящиеся в Сантк-Петербурге
data_spb_objects = data.query('locality_name == "Санкт-Петербург"')

# %%
# создадим сводную таблицу со средними ценами за кв. метр и средней общей стоимостью объектов 
# для каждого километра удалённости от центра Сантк-Петербурга
data_spb_objects_pivot = data_spb_objects.pivot_table(index='city_centers_nearest_km',
                                                      values=['price_per_square_meter','last_price'])

# на основании полученной сводной таблицы построим график
(data_spb_objects_pivot['last_price']
 .plot(grid=True,
       style='o-',
       figsize=(12, 7),
       color='g',
       legend=False))
plt.title('Средняя стоимсоть объектов для каждого километра от центра Санкт-Петербурга')
plt.xlabel('Удалённость от центра города (км)')
plt.ylabel('Средняя стоимость (10 млн руб.)')
plt.show()

# выведем сводную таблицу на экран
data_spb_objects_pivot.round(2)
# Out:
#                           last_price  price_per_square_meter
# city_centers_nearest_km
# 0.0                      31449115.85               245833.53
# 1.0                      21158706.73               176640.65
# 2.0                      17808292.86               157944.35
# 3.0                      11102708.38               121299.67
# 4.0                      13270609.65               133035.84
# 5.0                      14460813.18               140324.47
# 6.0                      15338418.39               151012.19
# 7.0                      14775152.59               156176.88
# 8.0                       9935921.44               125519.52
# 9.0                       6941773.47               113047.32
# 10.0                      6511375.49               112782.62
# 11.0                      6252637.85               108614.49
# 12.0                      5828544.72               107488.73
# 13.0                      6083140.87               108148.13
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Супер, корректно выделены квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислена средняя цена каждого километра.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Не мог определиться, какой параметр использовать: цену за квадратный метр или общую стоимость. В итоге решил изучить оба. 🤓
#
# </div>

# %% [markdown]
# На 27-м километре от центра Санкт-Петербурга средняя стоимость кв.м, как и общая стоимость, резко увеличивается.
# Проверим, почему так может быть.

# %%
# изучим, квартиры в каких населенных пунктах со стоимостью кв.м более 132115 руб. 
# находятся на удалении 27 км от центра города
data_pr_per_m_27_km = data.query('price_per_square_meter > 132115 & city_centers_nearest_km == 27')
print('Количество квартир на удалении 27 км от центра города \nи стоимостью кв.м более 132115 руб.:', len(data_pr_per_m_27_km))
data_pr_per_m_27_km.groupby('locality_name').agg({'total_images': 'count'})
# Out:
# Количество квартир на удалении 27 км от центра города
# и стоимостью кв.м более 132115 руб.: 12
#                  total_images
# locality_name
# Пушкин                     11
# Санкт-Петербург             1

# %% [markdown]
# Обнаружили, что **12** объектов, находящихся от центра Санкт-Петербурга на расстоянии **27 км**, имеют цену кв.м более **132115 руб.**
#
# Из них у **одного** объекта указана локация **Санкт-Петербург** и у **двенадцати** - **Пушкин**.
#
# Можно предположить, что как раз **Пушкин** и находится на данном расстоянии от центра города. А **одно** указанное значение **Санкт-Петербург** - человеческий фактор. В **Пушкине**, почти наверняка, есть жилые комплексы комфорт-класса и бизнес-класса.
#
# Таким образом, можно предположить, что резкое увеличение средней стоимости квадратного метра на отметке **27 км** может быть связано расположением на этом расстоянии каких-либо **элитных жилых комплексов**.

# %% [markdown]
# **Вывод:**
#
# Квартиры находящиеся на отметке **0**, то есть непосредственно в центре города имеют наибольшую цену за квадратный метр и, соответственно, наибольшую общую стоимость. Но уже начиная с первого километра удалённости от центра города средняя стоимость квартир ощутимо снижается (в 1.5 раза и более).
#
# Наблюдаем небольшое увеличение цен на удалении 6-7 км от центра. И далее, начиная с восьмого километра, цена плавно снижается.
#
# Исключение - 27-ой километр. На этой отметке цена резко увеличивается, что может быть связано с наличием элитной недвижимости.
#
# ---

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В исследовании использовался временной диапазон с **2014** по **2019** года.
#
# Изначальный датасет содержит **23699** строк (то есть объявлений о продаже) и **22** столбца.
#
# Предоставленные данные были проверены на правдоподобность и избавлены от выбивающихся значений.
#
# Пропуски были частично заполнены. Названия отдельных столбцов - приведены к общему стилю.
#
# Данные были проверены на наличие явных и неявных дубликатов. Неявные дубликаты были обработаны, что позволило уменьшить их количество.
#
# Для визуализации результатов были использованы:
# * круговые диаграммы
# * гистограммы
# * графики
# * диаграммы размаха
# * диаграммы рассеяния
# * тепловая карта
# * столбчатые диаграммы
# * матрица корреляции
# * сводные таблицы
#
# Для достижения целей исследования к изначальному набору данных были добавлены столбцы, содержащие информацию о:
# * цене за один кв.м
# * дне недели, месяце и годе публикации объявлений
# * типе этажа (последний, первый, другой)
# * расстоянии до центра города в целых км
#
# ---

# %% [markdown]
# **Подведём итоги исследования**
#
# В процессе исследования ***определили параметры среднестатистической квартиры*** для рынка недвижимости Санкт-Петербурга и пригородов:
# * общая площадь ***45-50 кв.м***
# * общая стоимость ***3.7-4.5 млн руб.***
# * имеющая ***1-2 комнаты***
# * с высотой потолков ***2.65 м***
# * находящаяся на ***1-4 этаже***
# * в ***5-ти*** либо ***9-ти*** этажном доме
# * на расстоянии около ***14 км*** от центра города
# * и удалении ***20 км*** от аэропорта
# * с парком в пределах ***0.5 км***
#
# ---
# **В отдельных столбцах были преобразованы типы данных, а именно:**
# * в столбце **"first_day_exposition"** *(дата публикации объявления)* тип данных был ***object***. Изменили на ***datetime***.
# * в столбце **"floors_total"** *(количество этажей в доме)* тип данных был ***float***. Изменили на целочисленные ***(int)***.
# * в столбце **"balcony"** *(количество балконов в квартире)* тип данных был ***float***. Изменили на целочисленные ***(int)***.
# * в столбце **"last_price"** *(общая стоимость квартиры)* тип данных был ***float***. Изменили на целочисленные ***(int)*** для удобства просмотра, то есть исключили копейки.
#
# ---
# **Было найдено очень большое количество пропущенных значений, но в основном в картографических и категориальных данных.**
#
# Всего пропусков: ***101441*** *(около 20% от всего объема данных)*
# Количество столбцов: **22**
# Количество столбцов с пропусками: **14**
#
# **В отдельных столбцах пропуски были заполнены:**
# * **"is_apartment"** *(является ли объект апартаментами)* - **Пропуски: 20924 (88.29%)** -  заполнили значением **"False"** (не апартаменты)
#
#
# * **"balcony"** *(количество балконов в квартире)* - **Пропуски: 11519 (48.61%)** - заполнили значением **"0"** (балконы в квартире отсутствуют)
#
#
# * **"ceiling_height"** *(высота потолков, м)* - **Пропуски: 9195 (38.80%)** - заполнили медианным значением ***(2.65)***, так как медиана наиболее устойчива к выбросам.
#
#
# * **"kitchen_area"** *(площадь кухни, кв.м)* - **Пропуски: 2278 (9.61%)** - заполнили, исходя из средней доли площади кухни в общей площади ***(0.187)***
#
#
# * **"living_area"** *(жилая площадь, кв.м)* - **Пропуски: 2278 (9.61%)** - заполнили, исходя из средней доли жилой площади в общей площади ***(0.565)***
#
#
# * **"floors_total"** *(всего этажей в доме)* - **Пропуски: 86 (0.36%)** - заполнили медианными значениями, сгруппированными по этажу
#
#
# * **"locality_name"** *(название населённого пункта)* - **Пропуски: 49 (0.21%)**  - заполнили ***26*** пропусков значением **"Санкт-Петербург"** для тех объектов, которые находятся от центра города на расстоянии ***меньшем или равном 12244.5 м***
#
# ---
# **Исходя из поставленных целей исследования, было определено:**
# * ***Касаемо скорости продажи квартир:***
#     * Среднее время продажи квартиры в Санкт-Петербурге составляет ***3 месяца (181 день)***
#     * Обычно продажа занимает от ***45 до 232 дней***
#     * Быстрая продажа - ***45 дней (1.5 месяца)***
#     * Долгая продажа - ***от 232 до 512 дней***
#
#
# * ***Касаемо факторов, оказывающих наибольшее влияние на общую стоимость объектов недвижимости:***
#     * Наибольеше влияние на общую стоимость объекта оказывает общая площадь. ***Чем выше общая площадь, тем дороже квартира.***
#     * Также на общую стоимость влияет тип этажа. ***Дороже те квартиры, которые находятся со второго по предпоследний этаж.***
#
#
# * ***Касаемо различий в стоимости одного квадратного метра в зависимости от локации:***
#     * Наблюдаем самую высокую среднюю стоимость квадратного метра в самом Санкт-Петербурге ***(114838.56 руб.)***. Причем максимальная цена квадратного метра наблюдается на расстоянии до ***2 км*** от центра ***(диапазон 158000 - 246000 руб./кв.м)***.
#     * Самый низкий показатель в Выборге ***(58141.91 руб.)***.
#
#
# * ***Касаемо того, какое влияние на стоимость квартир оказывает удаленность от центра города:***
#     * Квартиры находящиеся непосредственно в центре города имеют наибольшую общую стоимость ***(около 30 млн руб.)***.
#     * Но уже начиная с первого километра удалённости от центра города средняя стоимость квартир ощутимо снижается ***(до 18-20 млн руб.)***.
#     * Далее цены снижаются ***до 13 млн руб. к 4-му километру***, но на удалении ***6-7 км*** от центра цены немного подрастают ***(до 15 млн руб.)***.
#     * И начиная с ***восьмого километра*** по мере удаления от центра города прослеживается тенденция к плавному снижению стоимости квартир (за исключением жилых комплексов бизнес-класса).
#
# ---
# **Общие наблюдения по столбцам и данным:**
# * Столбец **"total_images"** - встречаются объявления **без фотографий**.
# * Столбец **"last_price"** - обнаружено подозрительное минимальное значение общей стоимости объекта: **12190 руб.**
# * Столбец **"total_area"** - обнаружено подозрительное минимальное значение общей площади: **12 кв.м.**
# * Столбец **"days_exposition"** - наблюдаем минимальное количество дней публикации объявлений, равное **1** день, и максимальное - **1580** дней.
# * Явные дубликаты обнаружены не были, то есть все объявления уникальны.
# * Названия населённых пунктов содержали неявные дубликаты и были приведены к лаконичному понятному виду.
# * Среди всех объявлений **521** квартира имеет **5** и более комнат, что составляет **2.2%** от всех квартир.
#
# ---
# **Был проведён исследовательсткй анализ данных и сделаны следующие выводы:**
#
# * ***По общей площади квартир:***
#     * Чаще всего встречаются квартиры с общей площадью ***от 30 до 60 кв.м***
#     * Площадь около ***45 кв.м*** - самый популярный вариант
#     * Реже всего встречаются квартиры общей площадью менее ***25 и более 100 кв.м***
#
#
# * ***По жилой площади квартир:***
#     * Чаще всего встречаются квартиры с жилой площадью ***от 15 до 40 кв.м***
#     * Площадь около ***15 кв.м*** - самый популярный вариант
#     * Реже всего встречаются квартиры с жилой площадью ***10 кв.м и менее, и более 60 кв.м***
#
#
# * ***По площади кухонь:***
#     * Чаще всего встречаются квартиры с площадью кухни ***от 5 до 12 кв.м***
#     * Площадь кухни около ***8 кв.м*** - самый популярный вариант
#     * Реже всего встречаются квартиры площадью кухни ***менее 5 и более 20 кв.м***
#
#
# * ***По общей стоимости объектов:***
#     * Среднее значение - ***5413456 руб.***, медиана - ***4550000 руб.***
#     * Чаще всего встречаются квартиры с ценой ***от 2.3 до 6 млн***
#     * Цена около ***3.75 млн*** - самый популярный вариант
#     * Реже всего встречаются квартиры с ценой ***менее 1 млн и более 10 млн***
#
#
# * ***По количеству комнат:***
#     * Чаще всего встречаются квартиры с ***1-2*** комнатами
#     * Реже всего встречаются квартиры с ***4 и более*** комнатами
#
#
# * ***По высоте потолков:***
#     * Чаще всего встречаются квартиры с высотой потолков от ***2.65*** метров
#     * Квартиры с высотой потолков от ***2.7*** и более встречаются редко
#
#
# * ***По этажу, на котром находится квартира:***
#     * Большинство квартир расположены на ***1-4*** этажах
#     * Реже встречаются квартиры на ***5-6 и 10*** этажах и ещё реже - ***выше 11*** этажа
#
#
# * ***По типу этажа:***
#     * ***25%*** от всех продаваемых квартир находятся либо на ***первом*** либо на ***последнем*** этажах.
#     * Большинство квартир расположено в диапозоне этажей между ***первым и последним***.
#
#
# * ***По количеству этажей в доме:***
#     * Чаще всего встречаются дома в ***5*** и ***9-10*** этажей.
#     * Дома с иной этажностью встречаются гораздо реже и распределены, в целом, равномерно.
#
#
# * ***По расстоянию от центра города:***
#     * Большинство объектов находится от центра города на расстоянии ***12-16 км***
#
#
# * ***По расстоянию от аэропорта:***
#     * Большинство объектов расположено на расстоянии ***15-25 км*** от аэропорта
#
#
# * ***По расстоянию от ближайшего парка:***
#     * Большинство объектов расположено на расстоянии ***300-600 метров*** от ближайшего парка
#
#
# * ***По дням недели публикации объявлений:***
#     * По ***будним*** дням объявления публикуются чаще, чем по ***выходным***.
#     * Наибольшая активность наблюдается по ***вторникам*** и ***четвергам***
#
#
# * ***По месяцам публикации объявлений:***
#     * Период наибольшей активности продавцов - конец зимы-начало весны ***(февраль-март)***.
#     *  Наименьшая активность наблюдается в ***мае*** и ***январе***
#
# ---

# %% [markdown]
# ---
# Не смог удержаться и решил проверить, как изменялась цена квадратного метра конкретно в Санкт-Петербурге с течением лет.
# В нашем случае - в рамках рассматриваемого периода 2014-2019 гг.

# %%
# для дальнейшего удобства переименуем столбец 'publication_year'
data = data.rename(columns={'publication_year': 'Год'})

# сделаем срез только по объявлениям, где локацией указан Санкт-Петербург
# сформируем сводную таблицу с ценой кв.м по годам и рассчитаем средние и медианные значения (из-за устойчивости к выбросам)
price_per_square_meter_by_year_in_spb = (data
 .query('locality_name == "Санкт-Петербург"')
 .pivot_table(index='Год', values='price_per_square_meter', aggfunc=['mean', 'median']))

# построим график изменения цены кв.м в Санкт-Петербурге в зависимости от года
price_per_square_meter_by_year_in_spb.plot(grid=True, style='o-', figsize=(8, 6))
plt.title('Изменение цены кв.м в Санкт-Петербурге по годам')
plt.ylabel('Средняя цена квадратного метра, руб.')
plt.legend(['Средняя цена кв.м', 'Медианная цена кв.м'])
plt.show()

# переименуем названия столбцов сводной таблицы
price_per_square_meter_by_year_in_spb.columns = ['Цена кв.м (средняя)', 'Цена кв.м (медианная)']

# выведем сводную таблицу на экран, округлив цены до двух знаков после запятой
price_per_square_meter_by_year_in_spb.round(2)
# Out:
#       Цена кв.м (средняя)  Цена кв.м (медианная)
# Год
# 2014            145049.07              133240.29
# 2015            118054.51              101984.13
# 2016            112804.79              100746.27
# 2017            111716.75              101612.90
# 2018            114476.24              106423.86
# 2019            123453.21              113541.67

# %% [markdown]
# **Вывод:**
#
# В **2014** году цена квадратного метра была довольнно высокой. За неимением данных до **2014** года трудно делать выводы, было ли это нормальным явлением для рынка недвижимости того времени, либо имел место быть некий всплеск роста цен.
#
# С **2015** года по **2018** цена квадратного метра жилой недвижимости в Санкт-Петербурге практически не менялась. Интересное было время!
#
# Начиная с **2019** года цены начали расти. Судя по тому, что мы имеем сейчас, в **2023** году, рост цен продолжился.
#
# ---

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Спасибо, очень хороший и подробный общий вывод, которые содержит все промежуточные результаты, добавлю несколько общих рекомендаций)
#
# В общем выводе хочется тезисно видеть все промежуточные выводы с цифрами. Это очень важно, поскольку топ-менеджеры, в большинстве своем, смотрят сразу сюда и только сюда...
#
# Тут важно обратиться к целям, которые были озвучены в самом начале и ответить на все вопросы. Важно оформить все тезисно и с цифрами. Еще важно описать все промежуточные выводы, которых не прописано в целях.
# Вкратце структура такая:
# - как были предобработаны данные(тут важно написать про изменения, если заполнялись пропуски или преобразовывались строки)
# - пройдись по целям и ответь на вопросы
# - добавь промежуточные выводы, которые считаешь нужным отметить
#
# Еще очень важно помнить, для кого ты делаешь проект, в зависимости от этого нужно сделать определенные акценты. В данном случае проект учебный, поэтому нужно ориентироваться по описанию.
#
# Для красивого оформления можешь воспользоваться [Кратким руководством по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Изменил общий вывод, учитывая твои рекомендации:
#
# 1. Написал про предобработку
# 2. Расписал выводы по целям исследования
# 3. Добавил краткие выводы по исследовательскому анализу данных
# 4. Везде подкрепил слова цифрами
# 5. Изменил оформление
#
# Надеюсь, стало лучше.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Спасибо за актуализацию вывода 👍
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что ты ведешь чек-лист, он помогает ничего не забыть!
#
# </div>
